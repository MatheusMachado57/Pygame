# %%
import pygame, sys
from pygame.locals import *

# set up pygame
pygame.init()

# set up the window
largura = 1100
altura  = 600
janela = pygame.display.set_mode((largura, altura), 0, 32)

branco    = (255,255,255)
azul      = (0,200,255)

relogio = pygame.time.Clock()

pygame.display.set_caption("Personagem")

#######################
M = [
{'rect':pygame.Rect(228, 150, 4, 4), 'color': (200, 100, 0)},
{'rect':pygame.Rect(232, 150, 4, 4), 'color': (0, 0, 128)},
{'rect':pygame.Rect(236, 150, 4, 4), 'color': (0, 0, 128)},
{'rect':pygame.Rect(240, 150, 4, 4), 'color': (0, 0, 128)},
{'rect':pygame.Rect(244, 150, 4, 4), 'color': (0, 0, 128)},
{'rect':pygame.Rect(248, 150, 4, 4), 'color': (200, 100, 0)},
{'rect':pygame.Rect(228, 154, 4, 4), 'color': (0, 0, 128)},
{'rect':pygame.Rect(232, 154, 4, 4), 'color': (0, 0, 128)},
{'rect':pygame.Rect(236, 154, 4, 4), 'color': (0, 0, 128)},
{'rect':pygame.Rect(240, 154, 4, 4), 'color': (0, 0, 128)},
{'rect':pygame.Rect(244, 154, 4, 4), 'color': (255, 255, 0)},
{'rect':pygame.Rect(248, 154, 4, 4), 'color': (0, 0, 128)},
{'rect':pygame.Rect(224, 158, 4, 4), 'color': (0, 0, 128)},
{'rect':pygame.Rect(228, 158, 4, 4), 'color': (0, 0, 128)},
{'rect':pygame.Rect(232, 158, 4, 4), 'color': (0, 0, 128)},
{'rect':pygame.Rect(236, 158, 4, 4), 'color': (0, 0, 128)},
{'rect':pygame.Rect(240, 158, 4, 4), 'color': (0, 0, 128)},
{'rect':pygame.Rect(244, 158, 4, 4), 'color': (0, 0, 128)},
{'rect':pygame.Rect(248, 158, 4, 4), 'color': (0, 0, 128)},
{'rect':pygame.Rect(252, 158, 4, 4), 'color': (0, 0, 128)},
{'rect':pygame.Rect(224, 162, 4, 4), 'color': (200, 100, 0)},
{'rect':pygame.Rect(228, 162, 4, 4), 'color': (200, 100, 0)},
{'rect':pygame.Rect(232, 162, 4, 4), 'color': (200, 100, 0)},
{'rect':pygame.Rect(236, 162, 4, 4), 'color': (200, 100, 0)},
{'rect':pygame.Rect(240, 162, 4, 4), 'color': (200, 100, 0)},
{'rect':pygame.Rect(244, 162, 4, 4), 'color': (200, 100, 0)},
{'rect':pygame.Rect(248, 162, 4, 4), 'color': (200, 100, 0)},
{'rect':pygame.Rect(252, 162, 4, 4), 'color': (200, 100, 0)},
{'rect':pygame.Rect(220, 166, 4, 4), 'color': (128, 0, 0)},
{'rect':pygame.Rect(224, 166, 4, 4), 'color': (128, 0, 0)},
{'rect':pygame.Rect(228, 166, 4, 4), 'color': (200, 100, 0)},
{'rect':pygame.Rect(232, 166, 4, 4), 'color': (200, 100, 0)},
{'rect':pygame.Rect(236, 166, 4, 4), 'color': (255, 255, 255)},
{'rect':pygame.Rect(240, 166, 4, 4), 'color': (255, 255, 255)},
{'rect':pygame.Rect(244, 166, 4, 4), 'color': (200, 100, 0)},
{'rect':pygame.Rect(248, 166, 4, 4), 'color': (255, 255, 255)},
{'rect':pygame.Rect(252, 166, 4, 4), 'color': (255, 255, 255)},
{'rect':pygame.Rect(256, 166, 4, 4), 'color': (128, 0, 0)},
{'rect':pygame.Rect(224, 170, 4, 4), 'color': (255, 200, 200)},
{'rect':pygame.Rect(228, 170, 4, 4), 'color': (200, 100, 0)},
{'rect':pygame.Rect(232, 170, 4, 4), 'color': (200, 100, 0)},
{'rect':pygame.Rect(236, 170, 4, 4), 'color': (255, 255, 255)},
{'rect':pygame.Rect(240, 170, 4, 4), 'color': (0, 0, 0)},
{'rect':pygame.Rect(244, 170, 4, 4), 'color': (200, 100, 0)},
{'rect':pygame.Rect(248, 170, 4, 4), 'color': (0, 0, 0)},
{'rect':pygame.Rect(252, 170, 4, 4), 'color': (255, 255, 255)},
{'rect':pygame.Rect(256, 170, 4, 4), 'color': (255, 200, 200)},
{'rect':pygame.Rect(224, 174, 4, 4), 'color': (200, 100, 0)},
{'rect':pygame.Rect(228, 174, 4, 4), 'color': (200, 100, 0)},
{'rect':pygame.Rect(232, 174, 4, 4), 'color': (200, 100, 0)},
{'rect':pygame.Rect(236, 174, 4, 4), 'color': (200, 100, 0)},
{'rect':pygame.Rect(240, 174, 4, 4), 'color': (255, 200, 200)},
{'rect':pygame.Rect(244, 174, 4, 4), 'color': (0, 0, 0)},
{'rect':pygame.Rect(248, 174, 4, 4), 'color': (200, 100, 0)},
{'rect':pygame.Rect(252, 174, 4, 4), 'color': (200, 100, 0)},
{'rect':pygame.Rect(228, 178, 4, 4), 'color': (200, 100, 0)},
{'rect':pygame.Rect(232, 178, 4, 4), 'color': (200, 100, 0)},
{'rect':pygame.Rect(236, 178, 4, 4), 'color': (200, 100, 0)},
{'rect':pygame.Rect(240, 178, 4, 4), 'color': (255, 200, 200)},
{'rect':pygame.Rect(244, 178, 4, 4), 'color': (255, 200, 200)},
{'rect':pygame.Rect(248, 178, 4, 4), 'color': (200, 100, 0)},
{'rect':pygame.Rect(252, 178, 4, 4), 'color': (200, 100, 0)},
{'rect':pygame.Rect(232, 182, 4, 4), 'color': (200, 100, 0)},
{'rect':pygame.Rect(236, 182, 4, 4), 'color': (200, 100, 0)},
{'rect':pygame.Rect(240, 182, 4, 4), 'color': (200, 100, 0)},
{'rect':pygame.Rect(244, 182, 4, 4), 'color': (200, 100, 0)},
{'rect':pygame.Rect(248, 182, 4, 4), 'color': (200, 100, 0)},
{'rect':pygame.Rect(228, 186, 4, 4), 'color': (0, 0, 128)},
{'rect':pygame.Rect(232, 186, 4, 4), 'color': (200, 100, 0)},
{'rect':pygame.Rect(236, 186, 4, 4), 'color': (200, 100, 0)},
{'rect':pygame.Rect(240, 186, 4, 4), 'color': (200, 100, 0)},
{'rect':pygame.Rect(244, 186, 4, 4), 'color': (200, 100, 0)},
{'rect':pygame.Rect(248, 186, 4, 4), 'color': (200, 100, 0)},
{'rect':pygame.Rect(252, 186, 4, 4), 'color': (0, 0, 128)},
{'rect':pygame.Rect(224, 190, 4, 4), 'color': (200, 100, 0)},
{'rect':pygame.Rect(228, 190, 4, 4), 'color': (0, 0, 128)},
{'rect':pygame.Rect(232, 190, 4, 4), 'color': (200, 100, 0)},
{'rect':pygame.Rect(236, 190, 4, 4), 'color': (128, 0, 0)},
{'rect':pygame.Rect(240, 190, 4, 4), 'color': (128, 0, 0)},
{'rect':pygame.Rect(244, 190, 4, 4), 'color': (128, 0, 0)},
{'rect':pygame.Rect(248, 190, 4, 4), 'color': (200, 100, 0)},
{'rect':pygame.Rect(252, 190, 4, 4), 'color': (0, 0, 128)},
{'rect':pygame.Rect(256, 190, 4, 4), 'color': (200, 100, 0)},
{'rect':pygame.Rect(224, 194, 4, 4), 'color': (200, 100, 0)},
{'rect':pygame.Rect(228, 194, 4, 4), 'color': (0, 0, 128)},
{'rect':pygame.Rect(232, 194, 4, 4), 'color': (200, 100, 0)},
{'rect':pygame.Rect(236, 194, 4, 4), 'color': (128, 0, 0)},
{'rect':pygame.Rect(240, 194, 4, 4), 'color': (128, 0, 0)},
{'rect':pygame.Rect(244, 194, 4, 4), 'color': (128, 0, 0)},
{'rect':pygame.Rect(248, 194, 4, 4), 'color': (200, 100, 0)},
{'rect':pygame.Rect(252, 194, 4, 4), 'color': (0, 0, 128)},
{'rect':pygame.Rect(256, 194, 4, 4), 'color': (200, 100, 0)},
{'rect':pygame.Rect(224, 198, 4, 4), 'color': (200, 100, 0)},
{'rect':pygame.Rect(228, 198, 4, 4), 'color': (0, 0, 128)},
{'rect':pygame.Rect(232, 198, 4, 4), 'color': (200, 100, 0)},
{'rect':pygame.Rect(236, 198, 4, 4), 'color': (128, 0, 0)},
{'rect':pygame.Rect(240, 198, 4, 4), 'color': (128, 0, 0)},
{'rect':pygame.Rect(244, 198, 4, 4), 'color': (128, 0, 0)},
{'rect':pygame.Rect(248, 198, 4, 4), 'color': (200, 100, 0)},
{'rect':pygame.Rect(252, 198, 4, 4), 'color': (0, 0, 128)},
{'rect':pygame.Rect(256, 198, 4, 4), 'color': (200, 100, 0)},
{'rect':pygame.Rect(224, 202, 4, 4), 'color': (200, 100, 0)},
{'rect':pygame.Rect(228, 202, 4, 4), 'color': (0, 0, 128)},
{'rect':pygame.Rect(232, 202, 4, 4), 'color': (200, 100, 0)},
{'rect':pygame.Rect(236, 202, 4, 4), 'color': (128, 0, 0)},
{'rect':pygame.Rect(240, 202, 4, 4), 'color': (128, 0, 0)},
{'rect':pygame.Rect(244, 202, 4, 4), 'color': (128, 0, 0)},
{'rect':pygame.Rect(248, 202, 4, 4), 'color': (200, 100, 0)},
{'rect':pygame.Rect(252, 202, 4, 4), 'color': (0, 0, 128)},
{'rect':pygame.Rect(256, 202, 4, 4), 'color': (200, 100, 0)},
{'rect':pygame.Rect(224, 206, 4, 4), 'color': (200, 100, 0)},
{'rect':pygame.Rect(228, 206, 4, 4), 'color': (0, 0, 128)},
{'rect':pygame.Rect(232, 206, 4, 4), 'color': (200, 100, 0)},
{'rect':pygame.Rect(236, 206, 4, 4), 'color': (128, 0, 0)},
{'rect':pygame.Rect(240, 206, 4, 4), 'color': (128, 0, 0)},
{'rect':pygame.Rect(244, 206, 4, 4), 'color': (128, 0, 0)},
{'rect':pygame.Rect(248, 206, 4, 4), 'color': (200, 100, 0)},
{'rect':pygame.Rect(252, 206, 4, 4), 'color': (0, 0, 128)},
{'rect':pygame.Rect(256, 206, 4, 4), 'color': (200, 100, 0)},
{'rect':pygame.Rect(224, 210, 4, 4), 'color': (200, 100, 0)},
{'rect':pygame.Rect(228, 210, 4, 4), 'color': (0, 0, 0)},
{'rect':pygame.Rect(232, 210, 4, 4), 'color': (255, 255, 0)},
{'rect':pygame.Rect(236, 210, 4, 4), 'color': (0, 0, 0)},
{'rect':pygame.Rect(240, 210, 4, 4), 'color': (0, 0, 0)},
{'rect':pygame.Rect(244, 210, 4, 4), 'color': (0, 0, 0)},
{'rect':pygame.Rect(248, 210, 4, 4), 'color': (255, 255, 0)},
{'rect':pygame.Rect(252, 210, 4, 4), 'color': (0, 0, 0)},
{'rect':pygame.Rect(256, 210, 4, 4), 'color': (200, 100, 0)},
{'rect':pygame.Rect(228, 214, 4, 4), 'color': (0, 0, 128)},
{'rect':pygame.Rect(232, 214, 4, 4), 'color': (0, 0, 128)},
{'rect':pygame.Rect(236, 214, 4, 4), 'color': (0, 0, 128)},
{'rect':pygame.Rect(240, 214, 4, 4), 'color': (0, 0, 128)},
{'rect':pygame.Rect(244, 214, 4, 4), 'color': (0, 0, 128)},
{'rect':pygame.Rect(248, 214, 4, 4), 'color': (0, 0, 128)},
{'rect':pygame.Rect(252, 214, 4, 4), 'color': (0, 0, 128)},
{'rect':pygame.Rect(232, 218, 4, 4), 'color': (0, 0, 128)},
{'rect':pygame.Rect(236, 218, 4, 4), 'color': (0, 0, 128)},
{'rect':pygame.Rect(240, 218, 4, 4), 'color': (0, 0, 128)},
{'rect':pygame.Rect(244, 218, 4, 4), 'color': (0, 0, 128)},
{'rect':pygame.Rect(248, 218, 4, 4), 'color': (0, 0, 128)},
{'rect':pygame.Rect(232, 222, 4, 4), 'color': (0, 0, 128)},
{'rect':pygame.Rect(236, 222, 4, 4), 'color': (0, 0, 128)},
{'rect':pygame.Rect(240, 222, 4, 4), 'color': (0, 0, 128)},
{'rect':pygame.Rect(244, 222, 4, 4), 'color': (0, 0, 128)},
{'rect':pygame.Rect(248, 222, 4, 4), 'color': (0, 0, 128)},
{'rect':pygame.Rect(232, 226, 4, 4), 'color': (128, 0, 0)},
{'rect':pygame.Rect(236, 226, 4, 4), 'color': (128, 0, 0)},
{'rect':pygame.Rect(240, 226, 4, 4), 'color': (0, 0, 0)},
{'rect':pygame.Rect(244, 226, 4, 4), 'color': (128, 0, 0)},
{'rect':pygame.Rect(248, 226, 4, 4), 'color': (0, 0, 0)},
{'rect':pygame.Rect(232, 230, 4, 4), 'color': (0, 0, 0)},
{'rect':pygame.Rect(236, 230, 4, 4), 'color': (128, 0, 0)},
{'rect':pygame.Rect(240, 230, 4, 4), 'color': (255, 255, 151)},
{'rect':pygame.Rect(244, 230, 4, 4), 'color': (0, 0, 0)},
{'rect':pygame.Rect(248, 230, 4, 4), 'color': (255, 255, 151)},
{'rect':pygame.Rect(252, 230, 4, 4), 'color': (0, 0, 0)},
{'rect':pygame.Rect(232, 234, 4, 4), 'color': (0, 0, 0)},
{'rect':pygame.Rect(236, 234, 4, 4), 'color': (0, 0, 0)},
{'rect':pygame.Rect(240, 234, 4, 4), 'color': (0, 0, 0)},
{'rect':pygame.Rect(244, 234, 4, 4), 'color': (0, 0, 0)},
{'rect':pygame.Rect(248, 234, 4, 4), 'color': (0, 0, 0)},
{'rect':pygame.Rect(252, 234, 4, 4), 'color': (0, 0, 0)}]
########################

def jogo():
    jogando = True
    solo = 500
    pos_x = 0
    pos_y = solo - 234
    t  = 10
    
    for i in range(len(M)): 
        M[i]["rect"] = [M[i]['rect'][0] + pos_x, M[i]['rect'][1] + pos_y, t, t]
    
    fundo = pygame.image.load('Terreno.PNG')
    nuvens = pygame.image.load("nuvens.png")
    
    while jogando:
        for event in pygame.event.get():
            if event.type == pygame.QUIT:
                jogando = False
        
        px = 0
        py = 0
        p = True 
        veloc0 = 4
        
        # Movimentos:
        comandos = pygame.key.get_pressed()
        
        if M[161]['rect'][1] >= solo + 45: p = True
        else: p = False    
            
        if comandos[pygame.K_UP] and p: py -= 8*veloc0       
        if comandos[pygame.K_LEFT]  and M[161]['rect'][0] > 30   : px -= veloc0
        if comandos[pygame.K_RIGHT] and M[161]['rect'][0] < 1090 : px += veloc0         
                
        # Atualização de Posições e Imagem:
         
        for i in range(len(M)):
            M[i]["rect"] = [M[i]['rect'][0] + px, M[i]['rect'][1] + py, t, t]
            # Gravidade:
            if 2>1:
                M[i]["rect"] = [M[i]['rect'][0], M[i]['rect'][1] + 5, t, t]  
                
        # Chegando ao chão:
        if M[161]['rect'][1] >= solo + 45:
            for i in range(len(M)):
                    M[i]["rect"] = [M[i]['rect'][0], M[i]['rect'][1] - 5, t, t]
                         
        janela.blit(nuvens, (0,0))
        janela.blit(fundo, (0, 550))
        for i in range(len(M)): pygame.draw.rect(janela, M[i]["color"], M[i]["rect"])
        
        # Regulando o tempo e atualizando a tela:
        relogio.tick(50)
        pygame.display.update()  

jogo()
pygame.quit()

# %%
len(M)
# Out:
# 162

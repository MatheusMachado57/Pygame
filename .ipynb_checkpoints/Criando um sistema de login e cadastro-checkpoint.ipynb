# %%
#! /usr/bin/env python
#  -*- coding: utf-8 -*-
#
# GUI module generated by PAGE version 5.2
#  in conjunction with Tcl version 8.6
#    May 18, 2020 07:39:03 PM -03  platform: Windows NT

import sys

try:
    import Tkinter as tk
except ImportError:
    import tkinter as tk

try:
    import ttk
    py3 = False
except ImportError:
    import tkinter.ttk as ttk
    py3 = True
    
class Toplevel1:
    def __init__(self):
        '''This class configures and populates the toplevel window.
           top is the toplevel containing window.'''
        _bgcolor = '#d9d9d9'  # X11 color: 'gray85'
        _fgcolor = '#000000'  # X11 color: 'black'
        _compcolor = '#d9d9d9' # X11 color: 'gray85'
        _ana1color = '#d9d9d9' # X11 color: 'gray85'
        _ana2color = '#ececec' # Closest X11 color: 'gray92'
        font10 = "-family {Segoe UI} -size 12 -slant italic"
        font9 = "-family {Calibri} -size 22"

        self.root = tk.Tk()        
        self.root.geometry("600x450+466+126")
        self.root.minsize(120, 1)
        self.root.maxsize(1370, 749)
        self.root.resizable(1, 1)
        self.root.title("New Toplevel")
        self.root.configure(background="#808080")

        self.Cadastro = tk.Frame(self.root)
        self.Cadastro.place(relx=0.05, rely=0.089, relheight=0.656, relwidth=0.625)

        self.Cadastro.configure(relief='groove')
        self.Cadastro.configure(borderwidth="2")
        self.Cadastro.configure(relief="groove")
        self.Cadastro.configure(background="#0000a0")
        self.Cadastro.configure(highlightbackground="#000080")
        self.Cadastro.configure(highlightcolor="#0000a0")

        self.Label1 = tk.Label(self.Cadastro)
        self.Label1.place(relx=0.075, rely=0.254, height=34, width=105)
        self.Label1.configure(background="#d9d9d9")
        self.Label1.configure(disabledforeground="#a3a3a3")
        self.Label1.configure(foreground="#000000")
        self.Label1.configure(text='''Usuário''')

        self.Label2 = tk.Label(self.Cadastro)
        self.Label2.place(relx=0.075, rely=0.508, height=33, width=105)
        self.Label2.configure(background="#d9d9d9")
        self.Label2.configure(disabledforeground="#a3a3a3")
        self.Label2.configure(foreground="#000000")
        self.Label2.configure(text='''Senha''')

        self.Label3 = tk.Label(self.Cadastro)
        self.Label3.place(relx=0.301, rely=0.037, height=44, width=142)
        self.Label3.configure(background="#0000a0")
        self.Label3.configure(disabledforeground="#a3a3a3")
        self.Label3.configure(font=font9)
        self.Label3.configure(foreground="#000000")
        self.Label3.configure(text='''Logando''')

        self.Entry1 = tk.Entry(self.Cadastro)
        self.Entry1.place(relx=0.075, rely=0.4,height=20, relwidth=0.437)
        self.Entry1.configure(background="white")
        self.Entry1.configure(disabledforeground="#a3a3a3")
        self.Entry1.configure(font="TkFixedFont")
        self.Entry1.configure(foreground="#000000")
        self.Entry1.configure(insertbackground="black")

        self.Entry2 = tk.Entry(self.Cadastro, show='*')
        self.Entry2.place(relx=0.075, rely=0.654,height=20, relwidth=0.437)
        self.Entry2.configure(background="white")
        self.Entry2.configure(disabledforeground="#a3a3a3")
        self.Entry2.configure(font="TkFixedFont")
        self.Entry2.configure(foreground="#000000")
        self.Entry2.configure(insertbackground="black")

        self.Button1 = tk.Button(self.Cadastro, command = self.LoginBackEnd)
        self.Button1.place(relx=0.08, rely=0.78, height=34, width=77)
        self.Button1.configure(activebackground="#ececec")
        self.Button1.configure(activeforeground="#000000")
        self.Button1.configure(background="#d9d9d9")
        self.Button1.configure(disabledforeground="#a3a3a3")
        self.Button1.configure(font=font10)
        self.Button1.configure(foreground="#000000")
        self.Button1.configure(highlightbackground="#d9d9d9")
        self.Button1.configure(highlightcolor="black")
        self.Button1.configure(pady="0")
        self.Button1.configure(text='''Login''')

        self.Button2 = tk.Button(self.Cadastro, command = self.Cadastrar)
        self.Button2.place(relx=0.32, rely=0.78, height=34, width=77)
        self.Button2.configure(activebackground="#ececec")
        self.Button2.configure(activeforeground="#000000")
        self.Button2.configure(background="#d9d9d9")
        self.Button2.configure(disabledforeground="#a3a3a3")
        self.Button2.configure(font=font10)
        self.Button2.configure(foreground="#000000")
        self.Button2.configure(highlightbackground="#d9d9d9")
        self.Button2.configure(highlightcolor="black")
        self.Button2.configure(pady="0")
        self.Button2.configure(text='''Cadastro''')
        
        self.root.mainloop()
    
     
    def Cadastrar(self):
                '''This class configures and populates the toplevel window.
                   top is the toplevel containing window.'''
                _bgcolor = '#d9d9d9'  # X11 color: 'gray85'
                _fgcolor = '#000000'  # X11 color: 'black'
                _compcolor = '#d9d9d9' # X11 color: 'gray85'
                _ana1color = '#d9d9d9' # X11 color: 'gray85'
                _ana2color = '#ececec' # Closest X11 color: 'gray92'
                font9 = "-family {Segoe UI} -size 20 -slant italic"
                 
                self.root = tk.Tk()    
                root.geometry("600x450+472+125")
                root.minsize(120, 1)
                root.maxsize(1370, 749)
                root.resizable(1, 1)
                root.title("Cadastrando")
                root.configure(background="#5151ff")

                self.Frame1 = tk.Frame(top)
                self.Frame1.place(relx=0.2, rely=0.156, relheight=0.633, relwidth=0.525)
                self.Frame1.configure(relief='groove')
                self.Frame1.configure(borderwidth="2")
                self.Frame1.configure(relief="groove")
                self.Frame1.configure(background="#000080")

                self.Label1 = tk.Label(self.Frame1)
                self.Label1.place(relx=0.063, rely=0.105, height=41, width=102)
                self.Label1.configure(background="#d9d9d9")
                self.Label1.configure(disabledforeground="#a3a3a3")
                self.Label1.configure(font=font9)
                self.Label1.configure(foreground="#000000")
                self.Label1.configure(text='''Nome:''')

                self.Entry1 = tk.Entry(self.Frame1)
                self.Entry1.place(relx=0.063, rely=0.281,height=20, relwidth=0.679)
                self.Entry1.configure(background="white")
                self.Entry1.configure(disabledforeground="#a3a3a3")
                self.Entry1.configure(font="TkFixedFont")
                self.Entry1.configure(foreground="#000000")
                self.Entry1.configure(insertbackground="black")

                self.Label2 = tk.Label(self.Frame1)
                self.Label2.place(relx=0.063, rely=0.386, height=41, width=103)
                self.Label2.configure(background="#d9d9d9")
                self.Label2.configure(disabledforeground="#a3a3a3")
                self.Label2.configure(font=font9)
                self.Label2.configure(foreground="#000000")
                self.Label2.configure(text='''Senha:''')

                self.Entry2 = tk.Entry(self.Frame1)
                self.Entry2.place(relx=0.063, rely=0.561,height=20, relwidth=0.679)
                self.Entry2.configure(background="white")
                self.Entry2.configure(disabledforeground="#a3a3a3")
                self.Entry2.configure(font="TkFixedFont")
                self.Entry2.configure(foreground="#000000")
                self.Entry2.configure(insertbackground="black")

                self.Button1 = tk.Button(self.Frame1)
                self.Button1.place(relx=0.063, rely=0.667, height=44, width=147)
                self.Button1.configure(activebackground="#ececec")
                self.Button1.configure(activeforeground="#000000")
                self.Button1.configure(background="#d9d9d9")
                self.Button1.configure(disabledforeground="#a3a3a3")
                self.Button1.configure(font=font9)
                self.Button1.configure(foreground="#000000")
                self.Button1.configure(highlightbackground="#d9d9d9")
                self.Button1.configure(highlightcolor="black")
                self.Button1.configure(pady="0")
                self.Button1.configure(text='''Cadastrar''')            
        
                self.root.mainloop()           
            
    def CadastrarBackEnd(self):
        try:
             with open('usuário.txt', 'a') as arquivoUsuario:
                    arquivoUsuario.write(self.Entry1Cadastro.get() + '\n')
         
             with open('senhas.txt', 'a') as arquivoUsuario:
                    arquivoUsuario.write(self.Entry2Cadastro.get() + '\n')
             
             self.root.destroy()
        except: 
               print('Houve um errro.')
                
    def LoginBackEnd(self): 
        with open('usuário.txt', 'r') as arquivoUsuario:
             usuários = arquivoUsuario.readlines()   
         
        with open('senhas.txt', 'r') as arquivoUsuario:
             senhas = arquivoUsuario.readlines()   
        
        usuários = list(map(lambda x: x.replace('\n',''), usuários))
        senhas   = list(map(lambda x: x.replace('\n',''), senhas  ))
        
        usuário = Entry1.get()
        senha   = Entry2.get()
        
        logado = False
        
        for i in range(len(senhas)):
            if usuário == usuários[i] and senha == senhas[i]:
                print('usuário logado') 
                logado = True
                self.root.destroy()
                
        if not logado: 
            print('algo deu errado') 
            self.root.destroy()

Toplevel1()
# Out:
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "C:\Users\mathe\anaconda3\lib\tkinter\__init__.py", line 1705, in __call__
#     return self.func(*args)
#   File "<ipython-input-16-785f0614e583>", line 130, in Cadastrar
#     root.geometry("600x450+472+125")
# NameError: name 'root' is not defined

# %%
import pygame, sys, time
from pygame.locals import *

# set up pygame
pygame.init()

# set up the window
largura = 1000
altura  = 600
#windowSurface = pygame.display.set_mode((largura, altura), 0, 32)

branco    = (255,255,255)
cinza     = (127,127,127)
verde     = (128,255,0)
azul      = (100,159,237)
vermesc   = (127,0,0)
rosa      = (255,200,200)
preto     = (0,0,0)
amarelo   = (255,255,0)
amarclar  = (255,255,151)
marrom    = (128,0,0)

#pygame.display.set_caption("Terreno")

def Terreno():
     
#    sair = True 
#    while sair: 
        
#        for event in pygame.event.get():
#                if event.type == pygame.QUIT:
#                    sair = False  
        
#        windowSurface.fill(azul)
 
        '''
        # planalto
        lp = []
        ap = []
        px = 200
        py = 500
        t  = 2
        
        for i in range(50):
            
            for i in range(3):
                py = 400
                px = px + 2
            
                q1 = 1
                for i in range(q1):
                    b = {"rect":pygame.Rect(px, py, t, t), "color":preto}
                    ap.append(b)
                    lp.append([px,py])
                    py += t    
            
                q2 = q1 + 3
                for i in range(q1,q2):
                    b = {"rect":pygame.Rect(px, py, t, t), "color":verde}
                    ap.append(b)
                    lp.append([px,py])
                    py += t
            
                q3 = q2 + 1
                for i in range(q2,q3):
                    b = {"rect":pygame.Rect(px, py, t, t), "color":preto}
                    ap.append(b)
                    lp.append([px,py])
                    py += t   
            
                q4 = q3 + 100
                for i in range(q3,q4):
                    b = {"rect":pygame.Rect(px, py, t, t), "color":marrom}
                    ap.append(b)
                    lp.append([px,py])
                    py += t   
        
            # Descida Gradual:
            py = 400
            px = px + 2
        
            q1 = 1
            for i in range(q1):
                b = {"rect":pygame.Rect(px, py, t, t), "color":preto}
                ap.append(b)
                lp.append([px,py])
                py += t        
        
            q2 = q1 + 4
            for i in range(q1,q2):
                b = {"rect":pygame.Rect(px, py, t, t), "color":verde}
                ap.append(b)
                lp.append([px,py])
                py += t
            
            q3 = q2 + 1
            for i in range(q2,q3):
                b = {"rect":pygame.Rect(px, py, t, t), "color":preto}
                ap.append(b)
                lp.append([px,py])
                py += t     
        
            q4 = q3 + 100
            for i in range(q3,q4):
                    b = {"rect":pygame.Rect(px, py, t, t), "color":marrom}
                    ap.append(b)
                    lp.append([px,py])
                    py += t   
                
            py = 400
            px = px + 2
        
            q1 = 1
            for i in range(q1):
                b = {"rect":pygame.Rect(px, py, t, t), "color":preto}
                ap.append(b)
                lp.append([px,py])
                py += t        
        
            q2 = q1 + 5
            for i in range(q1,q2):
                b = {"rect":pygame.Rect(px, py, t, t), "color":verde}
                ap.append(b)
                lp.append([px,py])
                py += t
            
            q3 = q2 + 1
            for i in range(q2,q3):
                b = {"rect":pygame.Rect(px, py, t, t), "color":preto}
                ap.append(b)
                lp.append([px,py])
                py += t     
        
            q4 = q3 + 100
            for i in range(q3,q4):
                    b = {"rect":pygame.Rect(px, py, t, t), "color":marrom}
                    ap.append(b)
                    lp.append([px,py])
                    py += t          
                
                
            for i in range(3):
                py = 400
                px = px + 2
            
                q1 = 1
                for i in range(q1):
                    b = {"rect":pygame.Rect(px, py, t, t), "color":preto}
                    ap.append(b)
                    lp.append([px,py])
                    py += t        
        
                q2 = q1 + 6
                for i in range(q1,q2):
                    b = {"rect":pygame.Rect(px, py, t, t), "color":verde}
                    ap.append(b)
                    lp.append([px,py])
                    py += t
            
                q3 = q2 + 1
                for i in range(q2,q3):
                    b = {"rect":pygame.Rect(px, py, t, t), "color":preto}
                    ap.append(b)
                    lp.append([px,py])
                    py += t     
        
                q4 = q3 + 100
                for i in range(q3,q4):
                    b = {"rect":pygame.Rect(px, py, t, t), "color":marrom}
                    ap.append(b)
                    lp.append([px,py])
                    py += t         
        
            py = 400
            px = px + 2
        
            q1 = 1
            for i in range(q1):
                b = {"rect":pygame.Rect(px, py, t, t), "color":preto}
                ap.append(b)
                lp.append([px,py])
                py += t        
        
            q2 = q1 + 5
            for i in range(q1,q2):
                b = {"rect":pygame.Rect(px, py, t, t), "color":verde}
                ap.append(b)
                lp.append([px,py])
                py += t
            
            q3 = q2 + 1
            for i in range(q2,q3):
                b = {"rect":pygame.Rect(px, py, t, t), "color":preto}
                ap.append(b)
                lp.append([px,py])
                py += t     
        
            q4 = q3 + 100
            for i in range(q3,q4):
                    b = {"rect":pygame.Rect(px, py, t, t), "color":marrom}
                    ap.append(b)
                    lp.append([px,py])
                    py += t        
                
            py = 400
            px = px + 2
        
            q1 = 1
            for i in range(q1):
                b = {"rect":pygame.Rect(px, py, t, t), "color":preto}
                ap.append(b)
                lp.append([px,py])
                py += t        
        
            q2 = q1 + 4
            for i in range(q1,q2):
                b = {"rect":pygame.Rect(px, py, t, t), "color":verde}
                ap.append(b)
                lp.append([px,py])
                py += t
            
            q3 = q2 + 1
            for i in range(q2,q3):
                b = {"rect":pygame.Rect(px, py, t, t), "color":preto}
                ap.append(b)
                lp.append([px,py])
                py += t     
        
            q4 = q3 + 100
            for i in range(q3,q4):
                    b = {"rect":pygame.Rect(px, py, t, t), "color":marrom}
                    ap.append(b)
                    lp.append([px,py])
                    py += t     
        
        py = 400 + t
        px = px + 2
                    
        for i in range(100):
            b = {"rect":pygame.Rect(px, py, t, t), "color":preto}
            ap.append(b)
            lp.append([px,py])
            py += t
            
            
        for i in range(len(ap)):
                 pygame.draw.rect(windowSurface, ap[i]["color"], ap[i]["rect"])  
        '''
                    
        # Terreno: ###############################################################################################
        ## 1 VERTICAL:
        l = []
        a = []
        px = -2
        py = 550
        t  = 2
        
        for i in range(100):
            
            for i in range(3):
                py = 550
                px = px + 2
            
                q1 = 1
                for i in range(q1):
                    b = {"rect":pygame.Rect(px, py, t, t), "color":preto}
                    a.append(b)
                    l.append([px,py])
                    py += t    
            
                q2 = q1 + 3
                for i in range(q1,q2):
                    b = {"rect":pygame.Rect(px, py, t, t), "color":verde}
                    a.append(b)
                    l.append([px,py])
                    py += t
            
                q3 = q2 + 1
                for i in range(q2,q3):
                    b = {"rect":pygame.Rect(px, py, t, t), "color":preto}
                    a.append(b)
                    l.append([px,py])
                    py += t   
            
                q4 = q3 + 50
                for i in range(q3,q4):
                    b = {"rect":pygame.Rect(px, py, t, t), "color":marrom}
                    a.append(b)
                    l.append([px,py])
                    py += t   
        
            # Descida Gradual:
            py = 550
            px = px + 2
        
            q1 = 1
            for i in range(q1):
                b = {"rect":pygame.Rect(px, py, t, t), "color":preto}
                a.append(b)
                l.append([px,py])
                py += t        
        
            q2 = q1 + 4
            for i in range(q1,q2):
                b = {"rect":pygame.Rect(px, py, t, t), "color":verde}
                a.append(b)
                l.append([px,py])
                py += t
            
            q3 = q2 + 1
            for i in range(q2,q3):
                b = {"rect":pygame.Rect(px, py, t, t), "color":preto}
                a.append(b)
                l.append([px,py])
                py += t     
        
            q4 = q3 + 45
            for i in range(q3,q4):
                    b = {"rect":pygame.Rect(px, py, t, t), "color":marrom}
                    a.append(b)
                    l.append([px,py])
                    py += t   
                
            py = 550
            px = px + 2
        
            q1 = 1
            for i in range(q1):
                b = {"rect":pygame.Rect(px, py, t, t), "color":preto}
                a.append(b)
                l.append([px,py])
                py += t        
        
            q2 = q1 + 5
            for i in range(q1,q2):
                b = {"rect":pygame.Rect(px, py, t, t), "color":verde}
                a.append(b)
                l.append([px,py])
                py += t
            
            q3 = q2 + 1
            for i in range(q2,q3):
                b = {"rect":pygame.Rect(px, py, t, t), "color":preto}
                a.append(b)
                l.append([px,py])
                py += t     
        
            q4 = q3 + 45
            for i in range(q3,q4):
                    b = {"rect":pygame.Rect(px, py, t, t), "color":marrom}
                    a.append(b)
                    l.append([px,py])
                    py += t          
                
                
            for i in range(3):
                py = 550
                px = px + 2
            
                q1 = 1
                for i in range(q1):
                    b = {"rect":pygame.Rect(px, py, t, t), "color":preto}
                    a.append(b)
                    l.append([px,py])
                    py += t        
        
                q2 = q1 + 6
                for i in range(q1,q2):
                    b = {"rect":pygame.Rect(px, py, t, t), "color":verde}
                    a.append(b)
                    l.append([px,py])
                    py += t
            
                q3 = q2 + 1
                for i in range(q2,q3):
                    b = {"rect":pygame.Rect(px, py, t, t), "color":preto}
                    a.append(b)
                    l.append([px,py])
                    py += t     
        
                q4 = q3 + 45
                for i in range(q3,q4):
                    b = {"rect":pygame.Rect(px, py, t, t), "color":marrom}
                    a.append(b)
                    l.append([px,py])
                    py += t         
        
            py = 550
            px = px + 2
        
            q1 = 1
            for i in range(q1):
                b = {"rect":pygame.Rect(px, py, t, t), "color":preto}
                a.append(b)
                l.append([px,py])
                py += t        
        
            q2 = q1 + 5
            for i in range(q1,q2):
                b = {"rect":pygame.Rect(px, py, t, t), "color":verde}
                a.append(b)
                l.append([px,py])
                py += t
            
            q3 = q2 + 1
            for i in range(q2,q3):
                b = {"rect":pygame.Rect(px, py, t, t), "color":preto}
                a.append(b)
                l.append([px,py])
                py += t     
        
            q4 = q3 + 45
            for i in range(q3,q4):
                    b = {"rect":pygame.Rect(px, py, t, t), "color":marrom}
                    a.append(b)
                    l.append([px,py])
                    py += t        
                
            py = 550
            px = px + 2
        
            q1 = 1
            for i in range(q1):
                b = {"rect":pygame.Rect(px, py, t, t), "color":preto}
                a.append(b)
                l.append([px,py])
                py += t        
        
            q2 = q1 + 4
            for i in range(q1,q2):
                b = {"rect":pygame.Rect(px, py, t, t), "color":verde}
                a.append(b)
                l.append([px,py])
                py += t
            
            q3 = q2 + 1
            for i in range(q2,q3):
                b = {"rect":pygame.Rect(px, py, t, t), "color":preto}
                a.append(b)
                l.append([px,py])
                py += t     
        
            q4 = q3 + 45
            for i in range(q3,q4):
                    b = {"rect":pygame.Rect(px, py, t, t), "color":marrom}
                    a.append(b)
                    l.append([px,py])
                    py += t                 
         
  #         for i in range(len(a)): print(a[i])
            
#        for i in range(len(a)):
#                 pygame.draw.rect(windowSurface, a[i]["color"], a[i]["rect"])      
            
#        pygame.display.update()

#Terreno()
# pygame.quit()

# %%
import pygame, sys, time
from pygame.locals import *

# set up pygame
pygame.init()

# set up the window
largura = 1000
altura  = 600
#windowSurface = pygame.display.set_mode((largura, altura), 0, 32)

branco    = (255,255,255)
cinza     = (127,127,127)
verde     = (128,255,0)
azul      = (100,159,237)
vermesc   = (127,0,0)
rosa      = (255,200,200)
preto     = (0,0,0)
amarelo   = (255,255,0)
amarclar  = (255,255,151)
marrom    = (128,0,0)

#pygame.display.set_caption("Terreno")

def Terreno():
     
#    sair = True 
#    while sair: 
        
#        for event in pygame.event.get():
#                if event.type == pygame.QUIT:
#                    sair = False  
        
#        windowSurface.fill(azul)
        
        l = []
        a = []
        px = -4
        py = 500
        t  = 2
        
        py = 550 + t
        px = px + 2
        
        
        for i in range(50):
            
            for i in range(3):
                py = 550
                px = px + 2
            
                q1 = 1
                for i in range(q1):
                    b = {"rect":pygame.Rect(px, py, t, t), "color":preto}
                    a.append(b)
                    l.append([px,py])
                    py += t    
            
                q2 = q1 + 3
                for i in range(q1,q2):
                    b = {"rect":pygame.Rect(px, py, t, t), "color":verde}
                    a.append(b)
                    l.append([px,py])
                    py += t
            
                q3 = q2 + 1
                for i in range(q2,q3):
                    b = {"rect":pygame.Rect(px, py, t, t), "color":preto}
                    a.append(b)
                    l.append([px,py])
                    py += t   
        
            # Descida Gradual:
            py = 550
            px = px + 2
        
            q1 = 1
            for i in range(q1):
                b = {"rect":pygame.Rect(px, py, t, t), "color":preto}
                a.append(b)
                l.append([px,py])
                py += t        
        
            q2 = q1 + 4
            for i in range(q1,q2):
                b = {"rect":pygame.Rect(px, py, t, t), "color":verde}
                a.append(b)
                l.append([px,py])
                py += t
            
            q3 = q2 + 1
            for i in range(q2,q3):
                b = {"rect":pygame.Rect(px, py, t, t), "color":preto}
                a.append(b)
                l.append([px,py])
                py += t     
        
                
            py = 550
            px = px + 2
        
            q1 = 1
            for i in range(q1):
                b = {"rect":pygame.Rect(px, py, t, t), "color":preto}
                a.append(b)
                l.append([px,py])
                py += t        
        
            q2 = q1 + 5
            for i in range(q1,q2):
                b = {"rect":pygame.Rect(px, py, t, t), "color":verde}
                a.append(b)
                l.append([px,py])
                py += t
            
            q3 = q2 + 1
            for i in range(q2,q3):
                b = {"rect":pygame.Rect(px, py, t, t), "color":preto}
                a.append(b)
                l.append([px,py])
                py += t          
                
                
            for i in range(3):
                py = 550
                px = px + 2
            
                q1 = 1
                for i in range(q1):
                    b = {"rect":pygame.Rect(px, py, t, t), "color":preto}
                    a.append(b)
                    l.append([px,py])
                    py += t        
        
                q2 = q1 + 6
                for i in range(q1,q2):
                    b = {"rect":pygame.Rect(px, py, t, t), "color":verde}
                    a.append(b)
                    l.append([px,py])
                    py += t
            
                q3 = q2 + 1
                for i in range(q2,q3):
                    b = {"rect":pygame.Rect(px, py, t, t), "color":preto}
                    a.append(b)
                    l.append([px,py])
                    py += t      
        
            py = 550
            px = px + 2
        
            q1 = 1
            for i in range(q1):
                b = {"rect":pygame.Rect(px, py, t, t), "color":preto}
                a.append(b)
                l.append([px,py])
                py += t        
        
            q2 = q1 + 5
            for i in range(q1,q2):
                b = {"rect":pygame.Rect(px, py, t, t), "color":verde}
                a.append(b)
                l.append([px,py])
                py += t
            
            q3 = q2 + 1
            for i in range(q2,q3):
                b = {"rect":pygame.Rect(px, py, t, t), "color":preto}
                a.append(b)
                l.append([px,py])
                py += t        
                
            py = 550
            px = px + 2
        
            q1 = 1
            for i in range(q1):
                b = {"rect":pygame.Rect(px, py, t, t), "color":preto}
                a.append(b)
                l.append([px,py])
                py += t        
        
            q2 = q1 + 4
            for i in range(q1,q2):
                b = {"rect":pygame.Rect(px, py, t, t), "color":verde}
                a.append(b)
                l.append([px,py])
                py += t
            
            q3 = q2 + 1
            for i in range(q2,q3):
                b = {"rect":pygame.Rect(px, py, t, t), "color":preto}
                a.append(b)
                l.append([px,py])
                py += t     
                    
         
             # for i in range(len(a)): print(a[i])
            
#        for i in range(len(a)): print(a[i])
            
#        for i in range(len(a)):
#                 pygame.draw.rect(windowSurface, a[i]["color"], a[i]["rect"])      
            
#        pygame.display.update()

        
#Terreno()
#pygame.quit()

# %%
T = [
{"rect":pygame.Rect(0, 550, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(0, 552, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(0, 554, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(0, 556, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(0, 558, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(2, 550, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(2, 552, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(2, 554, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(2, 556, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(2, 558, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(4, 550, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(4, 552, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(4, 554, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(4, 556, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(4, 558, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(6, 550, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(6, 552, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(6, 554, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(6, 556, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(6, 558, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(6, 560, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(8, 550, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(8, 552, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(8, 554, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(8, 556, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(8, 558, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(8, 560, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(8, 562, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(10, 550, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(10, 552, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(10, 554, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(10, 556, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(10, 558, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(10, 560, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(10, 562, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(10, 564, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(12, 550, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(12, 552, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(12, 554, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(12, 556, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(12, 558, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(12, 560, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(12, 562, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(12, 564, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(14, 550, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(14, 552, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(14, 554, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(14, 556, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(14, 558, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(14, 560, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(14, 562, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(14, 564, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(16, 550, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(16, 552, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(16, 554, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(16, 556, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(16, 558, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(16, 560, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(16, 562, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(18, 550, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(18, 552, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(18, 554, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(18, 556, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(18, 558, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(18, 560, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(20, 550, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(20, 552, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(20, 554, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(20, 556, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(20, 558, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(22, 550, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(22, 552, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(22, 554, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(22, 556, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(22, 558, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(24, 550, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(24, 552, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(24, 554, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(24, 556, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(24, 558, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(26, 550, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(26, 552, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(26, 554, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(26, 556, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(26, 558, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(26, 560, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(28, 550, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(28, 552, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(28, 554, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(28, 556, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(28, 558, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(28, 560, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(28, 562, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(30, 550, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(30, 552, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(30, 554, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(30, 556, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(30, 558, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(30, 560, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(30, 562, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(30, 564, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(32, 550, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(32, 552, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(32, 554, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(32, 556, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(32, 558, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(32, 560, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(32, 562, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(32, 564, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(34, 550, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(34, 552, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(34, 554, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(34, 556, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(34, 558, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(34, 560, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(34, 562, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(34, 564, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(36, 550, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(36, 552, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(36, 554, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(36, 556, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(36, 558, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(36, 560, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(36, 562, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(38, 550, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(38, 552, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(38, 554, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(38, 556, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(38, 558, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(38, 560, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(40, 550, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(40, 552, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(40, 554, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(40, 556, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(40, 558, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(42, 550, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(42, 552, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(42, 554, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(42, 556, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(42, 558, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(44, 550, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(44, 552, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(44, 554, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(44, 556, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(44, 558, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(46, 550, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(46, 552, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(46, 554, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(46, 556, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(46, 558, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(46, 560, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(48, 550, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(48, 552, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(48, 554, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(48, 556, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(48, 558, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(48, 560, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(48, 562, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(50, 550, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(50, 552, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(50, 554, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(50, 556, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(50, 558, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(50, 560, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(50, 562, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(50, 564, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(52, 550, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(52, 552, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(52, 554, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(52, 556, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(52, 558, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(52, 560, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(52, 562, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(52, 564, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(54, 550, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(54, 552, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(54, 554, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(54, 556, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(54, 558, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(54, 560, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(54, 562, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(54, 564, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(56, 550, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(56, 552, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(56, 554, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(56, 556, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(56, 558, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(56, 560, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(56, 562, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(58, 550, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(58, 552, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(58, 554, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(58, 556, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(58, 558, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(58, 560, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(60, 550, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(60, 552, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(60, 554, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(60, 556, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(60, 558, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(62, 550, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(62, 552, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(62, 554, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(62, 556, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(62, 558, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(64, 550, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(64, 552, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(64, 554, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(64, 556, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(64, 558, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(66, 550, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(66, 552, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(66, 554, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(66, 556, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(66, 558, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(66, 560, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(68, 550, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(68, 552, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(68, 554, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(68, 556, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(68, 558, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(68, 560, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(68, 562, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(70, 550, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(70, 552, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(70, 554, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(70, 556, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(70, 558, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(70, 560, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(70, 562, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(70, 564, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(72, 550, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(72, 552, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(72, 554, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(72, 556, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(72, 558, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(72, 560, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(72, 562, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(72, 564, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(74, 550, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(74, 552, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(74, 554, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(74, 556, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(74, 558, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(74, 560, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(74, 562, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(74, 564, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(76, 550, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(76, 552, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(76, 554, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(76, 556, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(76, 558, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(76, 560, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(76, 562, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(78, 550, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(78, 552, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(78, 554, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(78, 556, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(78, 558, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(78, 560, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(80, 550, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(80, 552, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(80, 554, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(80, 556, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(80, 558, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(82, 550, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(82, 552, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(82, 554, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(82, 556, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(82, 558, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(84, 550, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(84, 552, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(84, 554, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(84, 556, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(84, 558, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(86, 550, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(86, 552, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(86, 554, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(86, 556, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(86, 558, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(86, 560, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(88, 550, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(88, 552, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(88, 554, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(88, 556, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(88, 558, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(88, 560, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(88, 562, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(90, 550, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(90, 552, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(90, 554, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(90, 556, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(90, 558, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(90, 560, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(90, 562, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(90, 564, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(92, 550, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(92, 552, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(92, 554, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(92, 556, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(92, 558, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(92, 560, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(92, 562, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(92, 564, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(94, 550, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(94, 552, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(94, 554, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(94, 556, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(94, 558, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(94, 560, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(94, 562, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(94, 564, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(96, 550, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(96, 552, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(96, 554, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(96, 556, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(96, 558, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(96, 560, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(96, 562, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(98, 550, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(98, 552, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(98, 554, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(98, 556, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(98, 558, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(98, 560, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(100, 550, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(100, 552, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(100, 554, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(100, 556, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(100, 558, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(102, 550, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(102, 552, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(102, 554, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(102, 556, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(102, 558, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(104, 550, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(104, 552, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(104, 554, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(104, 556, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(104, 558, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(106, 550, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(106, 552, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(106, 554, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(106, 556, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(106, 558, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(106, 560, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(108, 550, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(108, 552, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(108, 554, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(108, 556, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(108, 558, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(108, 560, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(108, 562, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(110, 550, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(110, 552, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(110, 554, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(110, 556, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(110, 558, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(110, 560, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(110, 562, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(110, 564, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(112, 550, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(112, 552, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(112, 554, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(112, 556, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(112, 558, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(112, 560, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(112, 562, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(112, 564, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(114, 550, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(114, 552, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(114, 554, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(114, 556, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(114, 558, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(114, 560, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(114, 562, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(114, 564, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(116, 550, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(116, 552, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(116, 554, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(116, 556, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(116, 558, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(116, 560, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(116, 562, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(118, 550, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(118, 552, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(118, 554, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(118, 556, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(118, 558, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(118, 560, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(120, 550, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(120, 552, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(120, 554, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(120, 556, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(120, 558, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(122, 550, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(122, 552, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(122, 554, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(122, 556, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(122, 558, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(124, 550, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(124, 552, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(124, 554, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(124, 556, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(124, 558, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(126, 550, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(126, 552, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(126, 554, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(126, 556, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(126, 558, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(126, 560, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(128, 550, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(128, 552, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(128, 554, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(128, 556, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(128, 558, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(128, 560, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(128, 562, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(130, 550, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(130, 552, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(130, 554, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(130, 556, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(130, 558, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(130, 560, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(130, 562, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(130, 564, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(132, 550, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(132, 552, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(132, 554, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(132, 556, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(132, 558, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(132, 560, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(132, 562, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(132, 564, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(134, 550, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(134, 552, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(134, 554, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(134, 556, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(134, 558, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(134, 560, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(134, 562, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(134, 564, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(136, 550, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(136, 552, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(136, 554, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(136, 556, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(136, 558, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(136, 560, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(136, 562, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(138, 550, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(138, 552, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(138, 554, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(138, 556, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(138, 558, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(138, 560, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(140, 550, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(140, 552, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(140, 554, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(140, 556, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(140, 558, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(142, 550, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(142, 552, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(142, 554, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(142, 556, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(142, 558, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(144, 550, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(144, 552, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(144, 554, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(144, 556, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(144, 558, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(146, 550, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(146, 552, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(146, 554, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(146, 556, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(146, 558, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(146, 560, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(148, 550, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(148, 552, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(148, 554, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(148, 556, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(148, 558, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(148, 560, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(148, 562, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(150, 550, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(150, 552, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(150, 554, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(150, 556, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(150, 558, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(150, 560, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(150, 562, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(150, 564, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(152, 550, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(152, 552, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(152, 554, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(152, 556, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(152, 558, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(152, 560, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(152, 562, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(152, 564, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(154, 550, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(154, 552, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(154, 554, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(154, 556, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(154, 558, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(154, 560, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(154, 562, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(154, 564, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(156, 550, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(156, 552, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(156, 554, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(156, 556, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(156, 558, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(156, 560, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(156, 562, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(158, 550, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(158, 552, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(158, 554, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(158, 556, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(158, 558, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(158, 560, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(160, 550, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(160, 552, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(160, 554, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(160, 556, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(160, 558, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(162, 550, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(162, 552, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(162, 554, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(162, 556, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(162, 558, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(164, 550, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(164, 552, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(164, 554, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(164, 556, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(164, 558, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(166, 550, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(166, 552, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(166, 554, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(166, 556, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(166, 558, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(166, 560, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(168, 550, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(168, 552, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(168, 554, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(168, 556, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(168, 558, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(168, 560, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(168, 562, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(170, 550, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(170, 552, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(170, 554, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(170, 556, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(170, 558, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(170, 560, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(170, 562, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(170, 564, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(172, 550, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(172, 552, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(172, 554, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(172, 556, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(172, 558, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(172, 560, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(172, 562, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(172, 564, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(174, 550, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(174, 552, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(174, 554, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(174, 556, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(174, 558, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(174, 560, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(174, 562, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(174, 564, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(176, 550, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(176, 552, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(176, 554, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(176, 556, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(176, 558, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(176, 560, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(176, 562, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(178, 550, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(178, 552, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(178, 554, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(178, 556, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(178, 558, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(178, 560, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(180, 550, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(180, 552, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(180, 554, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(180, 556, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(180, 558, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(182, 550, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(182, 552, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(182, 554, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(182, 556, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(182, 558, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(184, 550, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(184, 552, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(184, 554, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(184, 556, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(184, 558, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(186, 550, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(186, 552, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(186, 554, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(186, 556, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(186, 558, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(186, 560, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(188, 550, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(188, 552, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(188, 554, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(188, 556, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(188, 558, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(188, 560, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(188, 562, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(190, 550, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(190, 552, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(190, 554, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(190, 556, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(190, 558, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(190, 560, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(190, 562, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(190, 564, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(192, 550, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(192, 552, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(192, 554, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(192, 556, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(192, 558, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(192, 560, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(192, 562, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(192, 564, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(194, 550, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(194, 552, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(194, 554, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(194, 556, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(194, 558, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(194, 560, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(194, 562, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(194, 564, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(196, 550, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(196, 552, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(196, 554, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(196, 556, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(196, 558, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(196, 560, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(196, 562, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(198, 550, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(198, 552, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(198, 554, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(198, 556, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(198, 558, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(198, 560, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(200, 550, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(200, 552, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(200, 554, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(200, 556, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(200, 558, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(202, 550, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(202, 552, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(202, 554, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(202, 556, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(202, 558, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(204, 550, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(204, 552, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(204, 554, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(204, 556, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(204, 558, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(206, 550, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(206, 552, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(206, 554, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(206, 556, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(206, 558, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(206, 560, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(208, 550, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(208, 552, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(208, 554, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(208, 556, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(208, 558, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(208, 560, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(208, 562, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(210, 550, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(210, 552, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(210, 554, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(210, 556, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(210, 558, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(210, 560, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(210, 562, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(210, 564, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(212, 550, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(212, 552, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(212, 554, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(212, 556, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(212, 558, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(212, 560, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(212, 562, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(212, 564, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(214, 550, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(214, 552, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(214, 554, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(214, 556, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(214, 558, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(214, 560, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(214, 562, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(214, 564, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(216, 550, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(216, 552, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(216, 554, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(216, 556, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(216, 558, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(216, 560, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(216, 562, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(218, 550, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(218, 552, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(218, 554, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(218, 556, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(218, 558, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(218, 560, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(220, 550, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(220, 552, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(220, 554, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(220, 556, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(220, 558, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(222, 550, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(222, 552, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(222, 554, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(222, 556, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(222, 558, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(224, 550, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(224, 552, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(224, 554, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(224, 556, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(224, 558, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(226, 550, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(226, 552, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(226, 554, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(226, 556, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(226, 558, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(226, 560, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(228, 550, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(228, 552, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(228, 554, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(228, 556, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(228, 558, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(228, 560, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(228, 562, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(230, 550, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(230, 552, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(230, 554, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(230, 556, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(230, 558, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(230, 560, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(230, 562, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(230, 564, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(232, 550, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(232, 552, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(232, 554, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(232, 556, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(232, 558, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(232, 560, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(232, 562, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(232, 564, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(234, 550, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(234, 552, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(234, 554, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(234, 556, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(234, 558, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(234, 560, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(234, 562, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(234, 564, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(236, 550, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(236, 552, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(236, 554, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(236, 556, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(236, 558, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(236, 560, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(236, 562, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(238, 550, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(238, 552, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(238, 554, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(238, 556, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(238, 558, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(238, 560, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(240, 550, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(240, 552, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(240, 554, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(240, 556, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(240, 558, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(242, 550, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(242, 552, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(242, 554, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(242, 556, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(242, 558, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(244, 550, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(244, 552, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(244, 554, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(244, 556, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(244, 558, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(246, 550, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(246, 552, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(246, 554, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(246, 556, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(246, 558, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(246, 560, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(248, 550, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(248, 552, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(248, 554, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(248, 556, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(248, 558, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(248, 560, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(248, 562, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(250, 550, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(250, 552, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(250, 554, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(250, 556, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(250, 558, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(250, 560, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(250, 562, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(250, 564, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(252, 550, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(252, 552, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(252, 554, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(252, 556, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(252, 558, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(252, 560, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(252, 562, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(252, 564, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(254, 550, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(254, 552, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(254, 554, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(254, 556, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(254, 558, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(254, 560, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(254, 562, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(254, 564, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(256, 550, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(256, 552, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(256, 554, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(256, 556, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(256, 558, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(256, 560, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(256, 562, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(258, 550, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(258, 552, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(258, 554, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(258, 556, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(258, 558, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(258, 560, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(260, 550, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(260, 552, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(260, 554, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(260, 556, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(260, 558, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(262, 550, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(262, 552, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(262, 554, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(262, 556, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(262, 558, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(264, 550, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(264, 552, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(264, 554, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(264, 556, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(264, 558, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(266, 550, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(266, 552, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(266, 554, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(266, 556, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(266, 558, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(266, 560, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(268, 550, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(268, 552, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(268, 554, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(268, 556, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(268, 558, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(268, 560, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(268, 562, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(270, 550, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(270, 552, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(270, 554, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(270, 556, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(270, 558, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(270, 560, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(270, 562, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(270, 564, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(272, 550, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(272, 552, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(272, 554, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(272, 556, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(272, 558, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(272, 560, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(272, 562, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(272, 564, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(274, 550, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(274, 552, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(274, 554, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(274, 556, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(274, 558, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(274, 560, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(274, 562, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(274, 564, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(276, 550, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(276, 552, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(276, 554, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(276, 556, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(276, 558, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(276, 560, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(276, 562, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(278, 550, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(278, 552, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(278, 554, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(278, 556, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(278, 558, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(278, 560, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(280, 550, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(280, 552, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(280, 554, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(280, 556, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(280, 558, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(282, 550, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(282, 552, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(282, 554, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(282, 556, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(282, 558, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(284, 550, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(284, 552, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(284, 554, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(284, 556, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(284, 558, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(286, 550, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(286, 552, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(286, 554, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(286, 556, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(286, 558, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(286, 560, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(288, 550, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(288, 552, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(288, 554, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(288, 556, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(288, 558, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(288, 560, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(288, 562, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(290, 550, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(290, 552, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(290, 554, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(290, 556, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(290, 558, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(290, 560, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(290, 562, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(290, 564, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(292, 550, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(292, 552, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(292, 554, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(292, 556, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(292, 558, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(292, 560, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(292, 562, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(292, 564, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(294, 550, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(294, 552, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(294, 554, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(294, 556, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(294, 558, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(294, 560, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(294, 562, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(294, 564, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(296, 550, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(296, 552, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(296, 554, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(296, 556, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(296, 558, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(296, 560, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(296, 562, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(298, 550, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(298, 552, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(298, 554, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(298, 556, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(298, 558, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(298, 560, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(300, 550, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(300, 552, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(300, 554, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(300, 556, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(300, 558, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(302, 550, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(302, 552, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(302, 554, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(302, 556, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(302, 558, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(304, 550, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(304, 552, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(304, 554, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(304, 556, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(304, 558, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(306, 550, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(306, 552, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(306, 554, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(306, 556, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(306, 558, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(306, 560, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(308, 550, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(308, 552, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(308, 554, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(308, 556, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(308, 558, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(308, 560, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(308, 562, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(310, 550, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(310, 552, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(310, 554, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(310, 556, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(310, 558, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(310, 560, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(310, 562, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(310, 564, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(312, 550, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(312, 552, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(312, 554, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(312, 556, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(312, 558, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(312, 560, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(312, 562, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(312, 564, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(314, 550, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(314, 552, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(314, 554, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(314, 556, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(314, 558, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(314, 560, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(314, 562, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(314, 564, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(316, 550, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(316, 552, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(316, 554, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(316, 556, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(316, 558, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(316, 560, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(316, 562, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(318, 550, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(318, 552, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(318, 554, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(318, 556, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(318, 558, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(318, 560, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(320, 550, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(320, 552, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(320, 554, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(320, 556, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(320, 558, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(322, 550, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(322, 552, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(322, 554, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(322, 556, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(322, 558, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(324, 550, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(324, 552, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(324, 554, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(324, 556, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(324, 558, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(326, 550, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(326, 552, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(326, 554, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(326, 556, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(326, 558, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(326, 560, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(328, 550, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(328, 552, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(328, 554, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(328, 556, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(328, 558, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(328, 560, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(328, 562, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(330, 550, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(330, 552, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(330, 554, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(330, 556, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(330, 558, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(330, 560, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(330, 562, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(330, 564, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(332, 550, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(332, 552, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(332, 554, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(332, 556, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(332, 558, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(332, 560, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(332, 562, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(332, 564, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(334, 550, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(334, 552, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(334, 554, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(334, 556, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(334, 558, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(334, 560, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(334, 562, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(334, 564, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(336, 550, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(336, 552, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(336, 554, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(336, 556, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(336, 558, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(336, 560, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(336, 562, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(338, 550, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(338, 552, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(338, 554, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(338, 556, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(338, 558, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(338, 560, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(340, 550, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(340, 552, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(340, 554, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(340, 556, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(340, 558, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(342, 550, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(342, 552, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(342, 554, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(342, 556, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(342, 558, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(344, 550, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(344, 552, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(344, 554, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(344, 556, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(344, 558, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(346, 550, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(346, 552, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(346, 554, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(346, 556, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(346, 558, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(346, 560, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(348, 550, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(348, 552, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(348, 554, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(348, 556, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(348, 558, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(348, 560, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(348, 562, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(350, 550, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(350, 552, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(350, 554, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(350, 556, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(350, 558, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(350, 560, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(350, 562, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(350, 564, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(352, 550, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(352, 552, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(352, 554, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(352, 556, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(352, 558, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(352, 560, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(352, 562, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(352, 564, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(354, 550, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(354, 552, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(354, 554, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(354, 556, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(354, 558, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(354, 560, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(354, 562, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(354, 564, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(356, 550, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(356, 552, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(356, 554, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(356, 556, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(356, 558, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(356, 560, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(356, 562, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(358, 550, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(358, 552, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(358, 554, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(358, 556, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(358, 558, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(358, 560, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(360, 550, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(360, 552, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(360, 554, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(360, 556, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(360, 558, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(362, 550, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(362, 552, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(362, 554, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(362, 556, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(362, 558, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(364, 550, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(364, 552, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(364, 554, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(364, 556, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(364, 558, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(366, 550, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(366, 552, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(366, 554, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(366, 556, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(366, 558, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(366, 560, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(368, 550, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(368, 552, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(368, 554, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(368, 556, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(368, 558, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(368, 560, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(368, 562, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(370, 550, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(370, 552, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(370, 554, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(370, 556, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(370, 558, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(370, 560, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(370, 562, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(370, 564, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(372, 550, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(372, 552, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(372, 554, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(372, 556, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(372, 558, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(372, 560, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(372, 562, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(372, 564, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(374, 550, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(374, 552, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(374, 554, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(374, 556, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(374, 558, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(374, 560, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(374, 562, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(374, 564, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(376, 550, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(376, 552, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(376, 554, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(376, 556, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(376, 558, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(376, 560, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(376, 562, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(378, 550, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(378, 552, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(378, 554, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(378, 556, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(378, 558, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(378, 560, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(380, 550, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(380, 552, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(380, 554, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(380, 556, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(380, 558, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(382, 550, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(382, 552, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(382, 554, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(382, 556, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(382, 558, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(384, 550, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(384, 552, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(384, 554, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(384, 556, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(384, 558, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(386, 550, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(386, 552, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(386, 554, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(386, 556, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(386, 558, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(386, 560, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(388, 550, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(388, 552, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(388, 554, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(388, 556, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(388, 558, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(388, 560, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(388, 562, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(390, 550, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(390, 552, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(390, 554, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(390, 556, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(390, 558, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(390, 560, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(390, 562, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(390, 564, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(392, 550, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(392, 552, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(392, 554, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(392, 556, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(392, 558, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(392, 560, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(392, 562, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(392, 564, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(394, 550, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(394, 552, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(394, 554, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(394, 556, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(394, 558, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(394, 560, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(394, 562, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(394, 564, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(396, 550, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(396, 552, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(396, 554, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(396, 556, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(396, 558, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(396, 560, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(396, 562, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(398, 550, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(398, 552, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(398, 554, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(398, 556, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(398, 558, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(398, 560, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(400, 550, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(400, 552, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(400, 554, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(400, 556, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(400, 558, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(402, 550, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(402, 552, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(402, 554, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(402, 556, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(402, 558, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(404, 550, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(404, 552, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(404, 554, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(404, 556, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(404, 558, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(406, 550, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(406, 552, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(406, 554, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(406, 556, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(406, 558, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(406, 560, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(408, 550, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(408, 552, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(408, 554, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(408, 556, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(408, 558, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(408, 560, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(408, 562, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(410, 550, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(410, 552, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(410, 554, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(410, 556, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(410, 558, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(410, 560, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(410, 562, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(410, 564, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(412, 550, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(412, 552, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(412, 554, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(412, 556, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(412, 558, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(412, 560, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(412, 562, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(412, 564, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(414, 550, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(414, 552, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(414, 554, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(414, 556, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(414, 558, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(414, 560, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(414, 562, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(414, 564, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(416, 550, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(416, 552, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(416, 554, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(416, 556, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(416, 558, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(416, 560, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(416, 562, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(418, 550, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(418, 552, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(418, 554, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(418, 556, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(418, 558, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(418, 560, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(420, 550, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(420, 552, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(420, 554, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(420, 556, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(420, 558, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(422, 550, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(422, 552, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(422, 554, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(422, 556, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(422, 558, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(424, 550, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(424, 552, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(424, 554, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(424, 556, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(424, 558, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(426, 550, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(426, 552, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(426, 554, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(426, 556, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(426, 558, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(426, 560, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(428, 550, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(428, 552, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(428, 554, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(428, 556, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(428, 558, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(428, 560, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(428, 562, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(430, 550, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(430, 552, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(430, 554, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(430, 556, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(430, 558, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(430, 560, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(430, 562, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(430, 564, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(432, 550, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(432, 552, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(432, 554, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(432, 556, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(432, 558, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(432, 560, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(432, 562, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(432, 564, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(434, 550, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(434, 552, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(434, 554, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(434, 556, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(434, 558, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(434, 560, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(434, 562, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(434, 564, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(436, 550, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(436, 552, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(436, 554, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(436, 556, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(436, 558, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(436, 560, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(436, 562, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(438, 550, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(438, 552, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(438, 554, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(438, 556, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(438, 558, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(438, 560, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(440, 550, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(440, 552, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(440, 554, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(440, 556, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(440, 558, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(442, 550, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(442, 552, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(442, 554, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(442, 556, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(442, 558, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(444, 550, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(444, 552, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(444, 554, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(444, 556, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(444, 558, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(446, 550, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(446, 552, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(446, 554, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(446, 556, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(446, 558, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(446, 560, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(448, 550, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(448, 552, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(448, 554, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(448, 556, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(448, 558, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(448, 560, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(448, 562, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(450, 550, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(450, 552, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(450, 554, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(450, 556, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(450, 558, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(450, 560, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(450, 562, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(450, 564, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(452, 550, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(452, 552, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(452, 554, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(452, 556, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(452, 558, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(452, 560, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(452, 562, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(452, 564, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(454, 550, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(454, 552, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(454, 554, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(454, 556, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(454, 558, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(454, 560, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(454, 562, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(454, 564, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(456, 550, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(456, 552, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(456, 554, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(456, 556, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(456, 558, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(456, 560, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(456, 562, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(458, 550, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(458, 552, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(458, 554, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(458, 556, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(458, 558, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(458, 560, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(460, 550, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(460, 552, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(460, 554, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(460, 556, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(460, 558, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(462, 550, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(462, 552, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(462, 554, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(462, 556, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(462, 558, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(464, 550, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(464, 552, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(464, 554, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(464, 556, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(464, 558, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(466, 550, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(466, 552, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(466, 554, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(466, 556, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(466, 558, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(466, 560, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(468, 550, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(468, 552, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(468, 554, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(468, 556, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(468, 558, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(468, 560, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(468, 562, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(470, 550, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(470, 552, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(470, 554, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(470, 556, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(470, 558, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(470, 560, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(470, 562, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(470, 564, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(472, 550, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(472, 552, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(472, 554, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(472, 556, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(472, 558, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(472, 560, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(472, 562, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(472, 564, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(474, 550, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(474, 552, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(474, 554, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(474, 556, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(474, 558, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(474, 560, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(474, 562, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(474, 564, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(476, 550, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(476, 552, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(476, 554, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(476, 556, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(476, 558, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(476, 560, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(476, 562, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(478, 550, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(478, 552, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(478, 554, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(478, 556, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(478, 558, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(478, 560, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(480, 550, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(480, 552, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(480, 554, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(480, 556, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(480, 558, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(482, 550, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(482, 552, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(482, 554, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(482, 556, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(482, 558, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(484, 550, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(484, 552, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(484, 554, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(484, 556, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(484, 558, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(486, 550, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(486, 552, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(486, 554, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(486, 556, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(486, 558, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(486, 560, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(488, 550, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(488, 552, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(488, 554, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(488, 556, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(488, 558, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(488, 560, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(488, 562, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(490, 550, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(490, 552, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(490, 554, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(490, 556, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(490, 558, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(490, 560, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(490, 562, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(490, 564, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(492, 550, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(492, 552, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(492, 554, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(492, 556, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(492, 558, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(492, 560, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(492, 562, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(492, 564, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(494, 550, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(494, 552, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(494, 554, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(494, 556, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(494, 558, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(494, 560, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(494, 562, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(494, 564, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(496, 550, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(496, 552, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(496, 554, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(496, 556, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(496, 558, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(496, 560, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(496, 562, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(498, 550, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(498, 552, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(498, 554, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(498, 556, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(498, 558, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(498, 560, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(500, 550, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(500, 552, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(500, 554, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(500, 556, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(500, 558, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(502, 550, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(502, 552, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(502, 554, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(502, 556, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(502, 558, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(504, 550, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(504, 552, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(504, 554, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(504, 556, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(504, 558, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(506, 550, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(506, 552, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(506, 554, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(506, 556, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(506, 558, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(506, 560, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(508, 550, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(508, 552, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(508, 554, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(508, 556, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(508, 558, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(508, 560, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(508, 562, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(510, 550, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(510, 552, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(510, 554, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(510, 556, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(510, 558, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(510, 560, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(510, 562, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(510, 564, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(512, 550, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(512, 552, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(512, 554, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(512, 556, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(512, 558, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(512, 560, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(512, 562, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(512, 564, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(514, 550, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(514, 552, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(514, 554, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(514, 556, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(514, 558, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(514, 560, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(514, 562, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(514, 564, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(516, 550, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(516, 552, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(516, 554, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(516, 556, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(516, 558, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(516, 560, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(516, 562, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(518, 550, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(518, 552, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(518, 554, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(518, 556, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(518, 558, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(518, 560, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(520, 550, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(520, 552, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(520, 554, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(520, 556, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(520, 558, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(522, 550, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(522, 552, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(522, 554, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(522, 556, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(522, 558, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(524, 550, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(524, 552, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(524, 554, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(524, 556, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(524, 558, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(526, 550, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(526, 552, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(526, 554, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(526, 556, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(526, 558, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(526, 560, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(528, 550, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(528, 552, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(528, 554, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(528, 556, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(528, 558, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(528, 560, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(528, 562, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(530, 550, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(530, 552, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(530, 554, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(530, 556, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(530, 558, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(530, 560, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(530, 562, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(530, 564, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(532, 550, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(532, 552, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(532, 554, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(532, 556, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(532, 558, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(532, 560, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(532, 562, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(532, 564, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(534, 550, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(534, 552, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(534, 554, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(534, 556, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(534, 558, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(534, 560, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(534, 562, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(534, 564, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(536, 550, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(536, 552, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(536, 554, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(536, 556, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(536, 558, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(536, 560, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(536, 562, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(538, 550, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(538, 552, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(538, 554, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(538, 556, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(538, 558, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(538, 560, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(540, 550, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(540, 552, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(540, 554, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(540, 556, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(540, 558, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(542, 550, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(542, 552, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(542, 554, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(542, 556, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(542, 558, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(544, 550, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(544, 552, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(544, 554, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(544, 556, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(544, 558, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(546, 550, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(546, 552, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(546, 554, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(546, 556, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(546, 558, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(546, 560, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(548, 550, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(548, 552, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(548, 554, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(548, 556, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(548, 558, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(548, 560, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(548, 562, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(550, 550, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(550, 552, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(550, 554, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(550, 556, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(550, 558, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(550, 560, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(550, 562, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(550, 564, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(552, 550, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(552, 552, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(552, 554, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(552, 556, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(552, 558, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(552, 560, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(552, 562, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(552, 564, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(554, 550, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(554, 552, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(554, 554, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(554, 556, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(554, 558, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(554, 560, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(554, 562, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(554, 564, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(556, 550, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(556, 552, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(556, 554, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(556, 556, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(556, 558, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(556, 560, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(556, 562, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(558, 550, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(558, 552, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(558, 554, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(558, 556, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(558, 558, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(558, 560, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(560, 550, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(560, 552, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(560, 554, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(560, 556, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(560, 558, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(562, 550, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(562, 552, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(562, 554, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(562, 556, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(562, 558, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(564, 550, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(564, 552, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(564, 554, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(564, 556, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(564, 558, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(566, 550, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(566, 552, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(566, 554, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(566, 556, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(566, 558, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(566, 560, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(568, 550, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(568, 552, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(568, 554, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(568, 556, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(568, 558, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(568, 560, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(568, 562, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(570, 550, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(570, 552, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(570, 554, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(570, 556, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(570, 558, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(570, 560, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(570, 562, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(570, 564, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(572, 550, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(572, 552, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(572, 554, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(572, 556, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(572, 558, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(572, 560, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(572, 562, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(572, 564, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(574, 550, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(574, 552, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(574, 554, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(574, 556, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(574, 558, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(574, 560, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(574, 562, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(574, 564, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(576, 550, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(576, 552, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(576, 554, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(576, 556, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(576, 558, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(576, 560, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(576, 562, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(578, 550, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(578, 552, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(578, 554, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(578, 556, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(578, 558, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(578, 560, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(580, 550, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(580, 552, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(580, 554, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(580, 556, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(580, 558, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(582, 550, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(582, 552, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(582, 554, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(582, 556, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(582, 558, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(584, 550, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(584, 552, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(584, 554, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(584, 556, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(584, 558, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(586, 550, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(586, 552, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(586, 554, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(586, 556, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(586, 558, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(586, 560, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(588, 550, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(588, 552, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(588, 554, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(588, 556, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(588, 558, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(588, 560, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(588, 562, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(590, 550, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(590, 552, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(590, 554, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(590, 556, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(590, 558, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(590, 560, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(590, 562, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(590, 564, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(592, 550, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(592, 552, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(592, 554, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(592, 556, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(592, 558, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(592, 560, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(592, 562, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(592, 564, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(594, 550, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(594, 552, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(594, 554, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(594, 556, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(594, 558, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(594, 560, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(594, 562, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(594, 564, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(596, 550, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(596, 552, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(596, 554, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(596, 556, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(596, 558, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(596, 560, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(596, 562, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(598, 550, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(598, 552, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(598, 554, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(598, 556, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(598, 558, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(598, 560, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(600, 550, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(600, 552, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(600, 554, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(600, 556, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(600, 558, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(602, 550, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(602, 552, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(602, 554, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(602, 556, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(602, 558, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(604, 550, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(604, 552, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(604, 554, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(604, 556, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(604, 558, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(606, 550, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(606, 552, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(606, 554, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(606, 556, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(606, 558, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(606, 560, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(608, 550, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(608, 552, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(608, 554, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(608, 556, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(608, 558, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(608, 560, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(608, 562, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(610, 550, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(610, 552, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(610, 554, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(610, 556, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(610, 558, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(610, 560, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(610, 562, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(610, 564, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(612, 550, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(612, 552, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(612, 554, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(612, 556, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(612, 558, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(612, 560, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(612, 562, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(612, 564, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(614, 550, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(614, 552, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(614, 554, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(614, 556, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(614, 558, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(614, 560, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(614, 562, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(614, 564, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(616, 550, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(616, 552, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(616, 554, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(616, 556, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(616, 558, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(616, 560, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(616, 562, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(618, 550, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(618, 552, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(618, 554, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(618, 556, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(618, 558, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(618, 560, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(620, 550, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(620, 552, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(620, 554, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(620, 556, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(620, 558, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(622, 550, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(622, 552, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(622, 554, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(622, 556, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(622, 558, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(624, 550, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(624, 552, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(624, 554, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(624, 556, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(624, 558, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(626, 550, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(626, 552, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(626, 554, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(626, 556, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(626, 558, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(626, 560, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(628, 550, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(628, 552, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(628, 554, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(628, 556, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(628, 558, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(628, 560, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(628, 562, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(630, 550, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(630, 552, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(630, 554, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(630, 556, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(630, 558, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(630, 560, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(630, 562, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(630, 564, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(632, 550, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(632, 552, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(632, 554, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(632, 556, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(632, 558, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(632, 560, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(632, 562, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(632, 564, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(634, 550, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(634, 552, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(634, 554, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(634, 556, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(634, 558, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(634, 560, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(634, 562, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(634, 564, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(636, 550, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(636, 552, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(636, 554, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(636, 556, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(636, 558, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(636, 560, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(636, 562, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(638, 550, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(638, 552, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(638, 554, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(638, 556, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(638, 558, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(638, 560, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(640, 550, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(640, 552, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(640, 554, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(640, 556, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(640, 558, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(642, 550, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(642, 552, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(642, 554, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(642, 556, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(642, 558, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(644, 550, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(644, 552, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(644, 554, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(644, 556, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(644, 558, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(646, 550, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(646, 552, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(646, 554, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(646, 556, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(646, 558, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(646, 560, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(648, 550, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(648, 552, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(648, 554, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(648, 556, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(648, 558, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(648, 560, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(648, 562, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(650, 550, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(650, 552, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(650, 554, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(650, 556, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(650, 558, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(650, 560, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(650, 562, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(650, 564, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(652, 550, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(652, 552, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(652, 554, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(652, 556, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(652, 558, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(652, 560, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(652, 562, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(652, 564, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(654, 550, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(654, 552, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(654, 554, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(654, 556, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(654, 558, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(654, 560, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(654, 562, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(654, 564, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(656, 550, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(656, 552, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(656, 554, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(656, 556, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(656, 558, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(656, 560, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(656, 562, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(658, 550, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(658, 552, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(658, 554, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(658, 556, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(658, 558, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(658, 560, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(660, 550, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(660, 552, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(660, 554, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(660, 556, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(660, 558, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(662, 550, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(662, 552, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(662, 554, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(662, 556, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(662, 558, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(664, 550, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(664, 552, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(664, 554, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(664, 556, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(664, 558, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(666, 550, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(666, 552, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(666, 554, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(666, 556, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(666, 558, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(666, 560, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(668, 550, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(668, 552, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(668, 554, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(668, 556, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(668, 558, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(668, 560, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(668, 562, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(670, 550, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(670, 552, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(670, 554, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(670, 556, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(670, 558, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(670, 560, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(670, 562, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(670, 564, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(672, 550, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(672, 552, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(672, 554, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(672, 556, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(672, 558, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(672, 560, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(672, 562, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(672, 564, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(674, 550, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(674, 552, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(674, 554, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(674, 556, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(674, 558, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(674, 560, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(674, 562, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(674, 564, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(676, 550, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(676, 552, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(676, 554, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(676, 556, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(676, 558, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(676, 560, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(676, 562, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(678, 550, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(678, 552, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(678, 554, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(678, 556, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(678, 558, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(678, 560, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(680, 550, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(680, 552, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(680, 554, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(680, 556, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(680, 558, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(682, 550, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(682, 552, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(682, 554, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(682, 556, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(682, 558, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(684, 550, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(684, 552, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(684, 554, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(684, 556, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(684, 558, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(686, 550, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(686, 552, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(686, 554, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(686, 556, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(686, 558, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(686, 560, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(688, 550, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(688, 552, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(688, 554, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(688, 556, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(688, 558, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(688, 560, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(688, 562, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(690, 550, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(690, 552, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(690, 554, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(690, 556, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(690, 558, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(690, 560, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(690, 562, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(690, 564, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(692, 550, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(692, 552, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(692, 554, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(692, 556, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(692, 558, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(692, 560, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(692, 562, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(692, 564, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(694, 550, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(694, 552, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(694, 554, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(694, 556, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(694, 558, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(694, 560, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(694, 562, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(694, 564, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(696, 550, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(696, 552, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(696, 554, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(696, 556, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(696, 558, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(696, 560, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(696, 562, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(698, 550, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(698, 552, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(698, 554, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(698, 556, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(698, 558, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(698, 560, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(700, 550, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(700, 552, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(700, 554, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(700, 556, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(700, 558, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(702, 550, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(702, 552, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(702, 554, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(702, 556, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(702, 558, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(704, 550, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(704, 552, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(704, 554, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(704, 556, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(704, 558, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(706, 550, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(706, 552, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(706, 554, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(706, 556, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(706, 558, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(706, 560, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(708, 550, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(708, 552, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(708, 554, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(708, 556, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(708, 558, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(708, 560, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(708, 562, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(710, 550, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(710, 552, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(710, 554, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(710, 556, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(710, 558, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(710, 560, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(710, 562, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(710, 564, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(712, 550, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(712, 552, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(712, 554, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(712, 556, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(712, 558, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(712, 560, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(712, 562, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(712, 564, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(714, 550, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(714, 552, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(714, 554, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(714, 556, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(714, 558, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(714, 560, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(714, 562, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(714, 564, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(716, 550, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(716, 552, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(716, 554, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(716, 556, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(716, 558, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(716, 560, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(716, 562, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(718, 550, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(718, 552, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(718, 554, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(718, 556, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(718, 558, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(718, 560, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(720, 550, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(720, 552, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(720, 554, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(720, 556, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(720, 558, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(722, 550, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(722, 552, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(722, 554, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(722, 556, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(722, 558, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(724, 550, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(724, 552, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(724, 554, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(724, 556, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(724, 558, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(726, 550, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(726, 552, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(726, 554, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(726, 556, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(726, 558, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(726, 560, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(728, 550, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(728, 552, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(728, 554, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(728, 556, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(728, 558, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(728, 560, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(728, 562, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(730, 550, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(730, 552, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(730, 554, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(730, 556, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(730, 558, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(730, 560, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(730, 562, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(730, 564, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(732, 550, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(732, 552, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(732, 554, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(732, 556, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(732, 558, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(732, 560, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(732, 562, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(732, 564, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(734, 550, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(734, 552, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(734, 554, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(734, 556, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(734, 558, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(734, 560, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(734, 562, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(734, 564, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(736, 550, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(736, 552, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(736, 554, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(736, 556, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(736, 558, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(736, 560, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(736, 562, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(738, 550, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(738, 552, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(738, 554, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(738, 556, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(738, 558, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(738, 560, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(740, 550, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(740, 552, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(740, 554, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(740, 556, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(740, 558, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(742, 550, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(742, 552, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(742, 554, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(742, 556, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(742, 558, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(744, 550, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(744, 552, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(744, 554, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(744, 556, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(744, 558, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(746, 550, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(746, 552, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(746, 554, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(746, 556, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(746, 558, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(746, 560, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(748, 550, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(748, 552, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(748, 554, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(748, 556, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(748, 558, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(748, 560, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(748, 562, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(750, 550, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(750, 552, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(750, 554, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(750, 556, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(750, 558, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(750, 560, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(750, 562, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(750, 564, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(752, 550, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(752, 552, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(752, 554, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(752, 556, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(752, 558, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(752, 560, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(752, 562, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(752, 564, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(754, 550, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(754, 552, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(754, 554, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(754, 556, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(754, 558, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(754, 560, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(754, 562, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(754, 564, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(756, 550, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(756, 552, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(756, 554, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(756, 556, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(756, 558, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(756, 560, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(756, 562, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(758, 550, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(758, 552, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(758, 554, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(758, 556, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(758, 558, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(758, 560, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(760, 550, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(760, 552, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(760, 554, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(760, 556, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(760, 558, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(762, 550, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(762, 552, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(762, 554, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(762, 556, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(762, 558, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(764, 550, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(764, 552, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(764, 554, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(764, 556, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(764, 558, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(766, 550, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(766, 552, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(766, 554, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(766, 556, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(766, 558, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(766, 560, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(768, 550, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(768, 552, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(768, 554, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(768, 556, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(768, 558, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(768, 560, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(768, 562, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(770, 550, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(770, 552, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(770, 554, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(770, 556, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(770, 558, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(770, 560, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(770, 562, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(770, 564, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(772, 550, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(772, 552, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(772, 554, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(772, 556, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(772, 558, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(772, 560, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(772, 562, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(772, 564, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(774, 550, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(774, 552, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(774, 554, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(774, 556, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(774, 558, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(774, 560, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(774, 562, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(774, 564, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(776, 550, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(776, 552, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(776, 554, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(776, 556, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(776, 558, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(776, 560, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(776, 562, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(778, 550, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(778, 552, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(778, 554, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(778, 556, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(778, 558, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(778, 560, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(780, 550, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(780, 552, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(780, 554, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(780, 556, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(780, 558, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(782, 550, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(782, 552, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(782, 554, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(782, 556, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(782, 558, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(784, 550, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(784, 552, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(784, 554, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(784, 556, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(784, 558, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(786, 550, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(786, 552, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(786, 554, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(786, 556, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(786, 558, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(786, 560, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(788, 550, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(788, 552, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(788, 554, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(788, 556, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(788, 558, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(788, 560, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(788, 562, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(790, 550, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(790, 552, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(790, 554, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(790, 556, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(790, 558, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(790, 560, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(790, 562, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(790, 564, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(792, 550, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(792, 552, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(792, 554, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(792, 556, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(792, 558, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(792, 560, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(792, 562, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(792, 564, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(794, 550, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(794, 552, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(794, 554, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(794, 556, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(794, 558, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(794, 560, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(794, 562, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(794, 564, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(796, 550, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(796, 552, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(796, 554, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(796, 556, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(796, 558, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(796, 560, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(796, 562, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(798, 550, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(798, 552, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(798, 554, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(798, 556, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(798, 558, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(798, 560, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(800, 550, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(800, 552, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(800, 554, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(800, 556, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(800, 558, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(802, 550, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(802, 552, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(802, 554, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(802, 556, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(802, 558, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(804, 550, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(804, 552, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(804, 554, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(804, 556, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(804, 558, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(806, 550, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(806, 552, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(806, 554, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(806, 556, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(806, 558, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(806, 560, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(808, 550, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(808, 552, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(808, 554, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(808, 556, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(808, 558, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(808, 560, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(808, 562, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(810, 550, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(810, 552, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(810, 554, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(810, 556, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(810, 558, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(810, 560, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(810, 562, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(810, 564, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(812, 550, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(812, 552, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(812, 554, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(812, 556, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(812, 558, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(812, 560, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(812, 562, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(812, 564, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(814, 550, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(814, 552, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(814, 554, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(814, 556, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(814, 558, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(814, 560, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(814, 562, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(814, 564, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(816, 550, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(816, 552, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(816, 554, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(816, 556, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(816, 558, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(816, 560, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(816, 562, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(818, 550, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(818, 552, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(818, 554, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(818, 556, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(818, 558, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(818, 560, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(820, 550, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(820, 552, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(820, 554, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(820, 556, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(820, 558, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(822, 550, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(822, 552, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(822, 554, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(822, 556, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(822, 558, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(824, 550, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(824, 552, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(824, 554, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(824, 556, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(824, 558, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(826, 550, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(826, 552, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(826, 554, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(826, 556, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(826, 558, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(826, 560, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(828, 550, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(828, 552, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(828, 554, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(828, 556, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(828, 558, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(828, 560, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(828, 562, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(830, 550, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(830, 552, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(830, 554, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(830, 556, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(830, 558, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(830, 560, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(830, 562, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(830, 564, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(832, 550, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(832, 552, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(832, 554, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(832, 556, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(832, 558, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(832, 560, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(832, 562, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(832, 564, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(834, 550, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(834, 552, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(834, 554, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(834, 556, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(834, 558, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(834, 560, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(834, 562, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(834, 564, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(836, 550, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(836, 552, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(836, 554, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(836, 556, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(836, 558, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(836, 560, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(836, 562, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(838, 550, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(838, 552, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(838, 554, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(838, 556, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(838, 558, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(838, 560, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(840, 550, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(840, 552, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(840, 554, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(840, 556, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(840, 558, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(842, 550, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(842, 552, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(842, 554, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(842, 556, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(842, 558, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(844, 550, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(844, 552, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(844, 554, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(844, 556, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(844, 558, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(846, 550, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(846, 552, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(846, 554, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(846, 556, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(846, 558, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(846, 560, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(848, 550, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(848, 552, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(848, 554, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(848, 556, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(848, 558, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(848, 560, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(848, 562, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(850, 550, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(850, 552, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(850, 554, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(850, 556, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(850, 558, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(850, 560, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(850, 562, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(850, 564, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(852, 550, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(852, 552, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(852, 554, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(852, 556, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(852, 558, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(852, 560, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(852, 562, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(852, 564, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(854, 550, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(854, 552, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(854, 554, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(854, 556, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(854, 558, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(854, 560, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(854, 562, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(854, 564, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(856, 550, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(856, 552, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(856, 554, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(856, 556, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(856, 558, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(856, 560, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(856, 562, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(858, 550, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(858, 552, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(858, 554, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(858, 556, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(858, 558, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(858, 560, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(860, 550, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(860, 552, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(860, 554, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(860, 556, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(860, 558, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(862, 550, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(862, 552, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(862, 554, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(862, 556, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(862, 558, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(864, 550, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(864, 552, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(864, 554, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(864, 556, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(864, 558, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(866, 550, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(866, 552, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(866, 554, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(866, 556, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(866, 558, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(866, 560, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(868, 550, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(868, 552, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(868, 554, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(868, 556, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(868, 558, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(868, 560, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(868, 562, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(870, 550, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(870, 552, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(870, 554, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(870, 556, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(870, 558, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(870, 560, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(870, 562, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(870, 564, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(872, 550, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(872, 552, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(872, 554, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(872, 556, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(872, 558, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(872, 560, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(872, 562, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(872, 564, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(874, 550, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(874, 552, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(874, 554, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(874, 556, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(874, 558, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(874, 560, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(874, 562, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(874, 564, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(876, 550, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(876, 552, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(876, 554, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(876, 556, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(876, 558, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(876, 560, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(876, 562, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(878, 550, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(878, 552, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(878, 554, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(878, 556, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(878, 558, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(878, 560, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(880, 550, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(880, 552, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(880, 554, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(880, 556, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(880, 558, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(882, 550, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(882, 552, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(882, 554, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(882, 556, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(882, 558, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(884, 550, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(884, 552, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(884, 554, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(884, 556, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(884, 558, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(886, 550, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(886, 552, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(886, 554, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(886, 556, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(886, 558, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(886, 560, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(888, 550, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(888, 552, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(888, 554, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(888, 556, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(888, 558, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(888, 560, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(888, 562, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(890, 550, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(890, 552, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(890, 554, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(890, 556, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(890, 558, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(890, 560, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(890, 562, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(890, 564, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(892, 550, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(892, 552, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(892, 554, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(892, 556, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(892, 558, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(892, 560, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(892, 562, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(892, 564, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(894, 550, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(894, 552, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(894, 554, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(894, 556, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(894, 558, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(894, 560, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(894, 562, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(894, 564, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(896, 550, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(896, 552, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(896, 554, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(896, 556, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(896, 558, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(896, 560, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(896, 562, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(898, 550, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(898, 552, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(898, 554, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(898, 556, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(898, 558, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(898, 560, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(900, 550, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(900, 552, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(900, 554, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(900, 556, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(900, 558, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(902, 550, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(902, 552, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(902, 554, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(902, 556, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(902, 558, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(904, 550, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(904, 552, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(904, 554, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(904, 556, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(904, 558, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(906, 550, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(906, 552, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(906, 554, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(906, 556, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(906, 558, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(906, 560, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(908, 550, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(908, 552, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(908, 554, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(908, 556, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(908, 558, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(908, 560, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(908, 562, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(910, 550, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(910, 552, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(910, 554, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(910, 556, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(910, 558, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(910, 560, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(910, 562, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(910, 564, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(912, 550, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(912, 552, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(912, 554, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(912, 556, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(912, 558, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(912, 560, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(912, 562, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(912, 564, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(914, 550, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(914, 552, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(914, 554, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(914, 556, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(914, 558, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(914, 560, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(914, 562, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(914, 564, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(916, 550, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(916, 552, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(916, 554, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(916, 556, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(916, 558, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(916, 560, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(916, 562, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(918, 550, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(918, 552, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(918, 554, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(918, 556, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(918, 558, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(918, 560, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(920, 550, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(920, 552, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(920, 554, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(920, 556, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(920, 558, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(922, 550, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(922, 552, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(922, 554, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(922, 556, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(922, 558, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(924, 550, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(924, 552, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(924, 554, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(924, 556, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(924, 558, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(926, 550, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(926, 552, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(926, 554, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(926, 556, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(926, 558, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(926, 560, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(928, 550, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(928, 552, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(928, 554, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(928, 556, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(928, 558, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(928, 560, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(928, 562, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(930, 550, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(930, 552, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(930, 554, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(930, 556, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(930, 558, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(930, 560, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(930, 562, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(930, 564, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(932, 550, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(932, 552, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(932, 554, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(932, 556, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(932, 558, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(932, 560, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(932, 562, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(932, 564, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(934, 550, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(934, 552, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(934, 554, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(934, 556, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(934, 558, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(934, 560, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(934, 562, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(934, 564, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(936, 550, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(936, 552, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(936, 554, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(936, 556, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(936, 558, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(936, 560, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(936, 562, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(938, 550, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(938, 552, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(938, 554, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(938, 556, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(938, 558, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(938, 560, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(940, 550, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(940, 552, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(940, 554, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(940, 556, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(940, 558, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(942, 550, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(942, 552, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(942, 554, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(942, 556, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(942, 558, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(944, 550, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(944, 552, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(944, 554, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(944, 556, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(944, 558, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(946, 550, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(946, 552, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(946, 554, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(946, 556, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(946, 558, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(946, 560, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(948, 550, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(948, 552, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(948, 554, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(948, 556, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(948, 558, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(948, 560, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(948, 562, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(950, 550, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(950, 552, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(950, 554, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(950, 556, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(950, 558, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(950, 560, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(950, 562, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(950, 564, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(952, 550, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(952, 552, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(952, 554, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(952, 556, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(952, 558, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(952, 560, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(952, 562, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(952, 564, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(954, 550, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(954, 552, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(954, 554, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(954, 556, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(954, 558, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(954, 560, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(954, 562, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(954, 564, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(956, 550, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(956, 552, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(956, 554, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(956, 556, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(956, 558, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(956, 560, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(956, 562, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(958, 550, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(958, 552, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(958, 554, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(958, 556, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(958, 558, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(958, 560, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(960, 550, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(960, 552, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(960, 554, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(960, 556, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(960, 558, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(962, 550, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(962, 552, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(962, 554, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(962, 556, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(962, 558, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(964, 550, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(964, 552, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(964, 554, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(964, 556, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(964, 558, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(966, 550, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(966, 552, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(966, 554, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(966, 556, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(966, 558, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(966, 560, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(968, 550, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(968, 552, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(968, 554, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(968, 556, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(968, 558, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(968, 560, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(968, 562, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(970, 550, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(970, 552, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(970, 554, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(970, 556, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(970, 558, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(970, 560, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(970, 562, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(970, 564, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(972, 550, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(972, 552, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(972, 554, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(972, 556, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(972, 558, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(972, 560, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(972, 562, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(972, 564, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(974, 550, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(974, 552, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(974, 554, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(974, 556, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(974, 558, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(974, 560, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(974, 562, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(974, 564, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(976, 550, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(976, 552, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(976, 554, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(976, 556, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(976, 558, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(976, 560, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(976, 562, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(978, 550, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(978, 552, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(978, 554, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(978, 556, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(978, 558, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(978, 560, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(980, 550, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(980, 552, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(980, 554, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(980, 556, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(980, 558, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(982, 550, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(982, 552, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(982, 554, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(982, 556, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(982, 558, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(984, 550, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(984, 552, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(984, 554, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(984, 556, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(984, 558, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(986, 550, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(986, 552, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(986, 554, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(986, 556, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(986, 558, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(986, 560, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(988, 550, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(988, 552, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(988, 554, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(988, 556, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(988, 558, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(988, 560, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(988, 562, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(990, 550, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(990, 552, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(990, 554, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(990, 556, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(990, 558, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(990, 560, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(990, 562, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(990, 564, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(992, 550, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(992, 552, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(992, 554, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(992, 556, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(992, 558, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(992, 560, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(992, 562, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(992, 564, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(994, 550, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(994, 552, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(994, 554, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(994, 556, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(994, 558, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(994, 560, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(994, 562, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(994, 564, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(996, 550, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(996, 552, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(996, 554, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(996, 556, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(996, 558, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(996, 560, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(996, 562, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(998, 550, 2, 2), 'color': (0, 0, 0)},
{"rect":pygame.Rect(998, 552, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(998, 554, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(998, 556, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(998, 558, 2, 2), 'color': (128, 255, 0)},
{"rect":pygame.Rect(998, 560, 2, 2), 'color': (0, 0, 0)},

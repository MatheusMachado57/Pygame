# %%
import pygame, sys
from pygame.locals import *

# set up pygame
pygame.init()

# set up the window
largura = 1100
altura  = 600
windowSurface = pygame.display.set_mode((largura, altura), 0, 32)

branco    = (255,255,255)

relogio = pygame.time.Clock()

pygame.display.set_caption("Personagem")

#######################
M = [
{'rect': pygame.Rect(114, 30, 2, 2), 'color': (150, 50, 50)},
{'rect': pygame.Rect(116, 30, 2, 2), 'color': (150, 50, 50)},
{'rect': pygame.Rect(118, 30, 2, 2), 'color': (150, 50, 50)},
{'rect': pygame.Rect(120, 30, 2, 2), 'color': (150, 50, 50)},
{'rect': pygame.Rect(122, 30, 2, 2), 'color': (150, 50, 50)},
{'rect': pygame.Rect(110, 32, 2, 2), 'color': (150, 50, 50)},
{'rect': pygame.Rect(112, 32, 2, 2), 'color': (150, 50, 50)},
{'rect': pygame.Rect(114, 32, 2, 2), 'color': (255, 0, 0)},
{'rect': pygame.Rect(116, 32, 2, 2), 'color': (255, 0, 0)},
{'rect': pygame.Rect(118, 32, 2, 2), 'color': (255, 255, 151)},
{'rect': pygame.Rect(120, 32, 2, 2), 'color': (255, 0, 0)},
{'rect': pygame.Rect(122, 32, 2, 2), 'color': (255, 0, 0)},
{'rect': pygame.Rect(124, 32, 2, 2), 'color': (150, 50, 50)},
{'rect': pygame.Rect(108, 34, 2, 2), 'color': (150, 50, 50)},
{'rect': pygame.Rect(110, 34, 2, 2), 'color': (255, 0, 0)},
{'rect': pygame.Rect(112, 34, 2, 2), 'color': (255, 0, 0)},
{'rect': pygame.Rect(114, 34, 2, 2), 'color': (200, 0, 128)},
{'rect': pygame.Rect(116, 34, 2, 2), 'color': (200, 200, 0)},
{'rect': pygame.Rect(118, 34, 2, 2), 'color': (255, 255, 151)},
{'rect': pygame.Rect(120, 34, 2, 2), 'color': (255, 255, 255)},
{'rect': pygame.Rect(122, 34, 2, 2), 'color': (200, 0, 128)},
{'rect': pygame.Rect(124, 34, 2, 2), 'color': (150, 50, 50)},
{'rect': pygame.Rect(106, 36, 2, 2), 'color': (150, 50, 50)},
{'rect': pygame.Rect(108, 36, 2, 2), 'color': (255, 0, 0)},
{'rect': pygame.Rect(110, 36, 2, 2), 'color': (200, 0, 128)},
{'rect': pygame.Rect(112, 36, 2, 2), 'color': (200, 0, 128)},
{'rect': pygame.Rect(114, 36, 2, 2), 'color': (0, 0, 0)},
{'rect': pygame.Rect(116, 36, 2, 2), 'color': (0, 0, 0)},
{'rect': pygame.Rect(118, 36, 2, 2), 'color': (0, 0, 0)},
{'rect': pygame.Rect(120, 36, 2, 2), 'color': (0, 0, 0)},
{'rect': pygame.Rect(122, 36, 2, 2), 'color': (0, 0, 0)},
{'rect': pygame.Rect(124, 36, 2, 2), 'color': (0, 0, 0)},
{'rect': pygame.Rect(126, 36, 2, 2), 'color': (0, 0, 0)},
{'rect': pygame.Rect(104, 38, 2, 2), 'color': (150, 50, 50)},
{'rect': pygame.Rect(106, 38, 2, 2), 'color': (255, 0, 0)},
{'rect': pygame.Rect(108, 38, 2, 2), 'color': (200, 0, 128)},
{'rect': pygame.Rect(110, 38, 2, 2), 'color': (0, 0, 0)},
{'rect': pygame.Rect(112, 38, 2, 2), 'color': (0, 0, 0)},
{'rect': pygame.Rect(114, 38, 2, 2), 'color': (0, 0, 0)},
{'rect': pygame.Rect(116, 38, 2, 2), 'color': (0, 0, 0)},
{'rect': pygame.Rect(118, 38, 2, 2), 'color': (0, 0, 0)},
{'rect': pygame.Rect(120, 38, 2, 2), 'color': (0, 0, 0)},
{'rect': pygame.Rect(122, 38, 2, 2), 'color': (0, 0, 0)},
{'rect': pygame.Rect(124, 38, 2, 2), 'color': (0, 0, 0)},
{'rect': pygame.Rect(126, 38, 2, 2), 'color': (0, 0, 0)},
{'rect': pygame.Rect(128, 38, 2, 2), 'color': (0, 0, 0)},
{'rect': pygame.Rect(102, 40, 2, 2), 'color': (150, 50, 50)},
{'rect': pygame.Rect(104, 40, 2, 2), 'color': (200, 0, 128)},
{'rect': pygame.Rect(106, 40, 2, 2), 'color': (200, 0, 128)},
{'rect': pygame.Rect(108, 40, 2, 2), 'color': (0, 0, 0)},
{'rect': pygame.Rect(110, 40, 2, 2), 'color': (0, 0, 0)},
{'rect': pygame.Rect(112, 40, 2, 2), 'color': (0, 0, 0)},
{'rect': pygame.Rect(114, 40, 2, 2), 'color': (0, 0, 0)},
{'rect': pygame.Rect(116, 40, 2, 2), 'color': (0, 0, 0)},
{'rect': pygame.Rect(118, 40, 2, 2), 'color': (0, 0, 0)},
{'rect': pygame.Rect(120, 40, 2, 2), 'color': (0, 0, 0)},
{'rect': pygame.Rect(122, 40, 2, 2), 'color': (0, 0, 0)},
{'rect': pygame.Rect(124, 40, 2, 2), 'color': (0, 0, 0)},
{'rect': pygame.Rect(126, 40, 2, 2), 'color': (0, 0, 0)},
{'rect': pygame.Rect(128, 40, 2, 2), 'color': (0, 0, 0)},
{'rect': pygame.Rect(102, 42, 2, 2), 'color': (150, 50, 50)},
{'rect': pygame.Rect(104, 42, 2, 2), 'color': (200, 0, 128)},
{'rect': pygame.Rect(106, 42, 2, 2), 'color': (200, 0, 128)},
{'rect': pygame.Rect(108, 42, 2, 2), 'color': (0, 0, 0)},
{'rect': pygame.Rect(110, 42, 2, 2), 'color': (0, 0, 0)},
{'rect': pygame.Rect(112, 42, 2, 2), 'color': (255, 200, 200)},
{'rect': pygame.Rect(114, 42, 2, 2), 'color': (255, 255, 255)},
{'rect': pygame.Rect(116, 42, 2, 2), 'color': (255, 255, 255)},
{'rect': pygame.Rect(118, 42, 2, 2), 'color': (255, 200, 200)},
{'rect': pygame.Rect(120, 42, 2, 2), 'color': (255, 255, 255)},
{'rect': pygame.Rect(122, 42, 2, 2), 'color': (255, 255, 255)},
{'rect': pygame.Rect(124, 42, 2, 2), 'color': (0, 0, 0)},
{'rect': pygame.Rect(126, 42, 2, 2), 'color': (0, 0, 0)},
{'rect': pygame.Rect(102, 44, 2, 2), 'color': (255, 200, 200)},
{'rect': pygame.Rect(104, 44, 2, 2), 'color': (255, 200, 255)},
{'rect': pygame.Rect(106, 44, 2, 2), 'color': (0, 0, 0)},
{'rect': pygame.Rect(108, 44, 2, 2), 'color': (0, 0, 0)},
{'rect': pygame.Rect(110, 44, 2, 2), 'color': (255, 200, 200)},
{'rect': pygame.Rect(112, 44, 2, 2), 'color': (255, 200, 200)},
{'rect': pygame.Rect(114, 44, 2, 2), 'color': (255, 255, 255)},
{'rect': pygame.Rect(116, 44, 2, 2), 'color': (0, 0, 0)},
{'rect': pygame.Rect(118, 44, 2, 2), 'color': (255, 200, 255)},
{'rect': pygame.Rect(120, 44, 2, 2), 'color': (255, 255, 255)},
{'rect': pygame.Rect(122, 44, 2, 2), 'color': (0, 0, 0)},
{'rect': pygame.Rect(124, 44, 2, 2), 'color': (128, 0, 0)},
{'rect': pygame.Rect(100, 46, 2, 2), 'color': (255, 200, 200)},
{'rect': pygame.Rect(102, 46, 2, 2), 'color': (128, 0, 0)},
{'rect': pygame.Rect(104, 46, 2, 2), 'color': (255, 200, 255)},
{'rect': pygame.Rect(106, 46, 2, 2), 'color': (0, 0, 0)},
{'rect': pygame.Rect(108, 46, 2, 2), 'color': (0, 0, 0)},
{'rect': pygame.Rect(110, 46, 2, 2), 'color': (255, 200, 200)},
{'rect': pygame.Rect(112, 46, 2, 2), 'color': (255, 200, 255)},
{'rect': pygame.Rect(114, 46, 2, 2), 'color': (255, 255, 255)},
{'rect': pygame.Rect(116, 46, 2, 2), 'color': (0, 0, 0)},
{'rect': pygame.Rect(118, 46, 2, 2), 'color': (255, 200, 255)},
{'rect': pygame.Rect(120, 46, 2, 2), 'color': (255, 255, 255)},
{'rect': pygame.Rect(122, 46, 2, 2), 'color': (0, 0, 0)},
{'rect': pygame.Rect(124, 46, 2, 2), 'color': (255, 200, 255)},
{'rect': pygame.Rect(126, 46, 2, 2), 'color': (128, 0, 0)},
{'rect': pygame.Rect(100, 48, 2, 2), 'color': (255, 200, 200)},
{'rect': pygame.Rect(102, 48, 2, 2), 'color': (128, 0, 0)},
{'rect': pygame.Rect(104, 48, 2, 2), 'color': (255, 200, 200)},
{'rect': pygame.Rect(106, 48, 2, 2), 'color': (0, 0, 0)},
{'rect': pygame.Rect(108, 48, 2, 2), 'color': (0, 0, 0)},
{'rect': pygame.Rect(110, 48, 2, 2), 'color': (0, 0, 0)},
{'rect': pygame.Rect(112, 48, 2, 2), 'color': (255, 200, 255)},
{'rect': pygame.Rect(114, 48, 2, 2), 'color': (255, 200, 255)},
{'rect': pygame.Rect(116, 48, 2, 2), 'color': (255, 200, 200)},
{'rect': pygame.Rect(118, 48, 2, 2), 'color': (255, 200, 200)},
{'rect': pygame.Rect(120, 48, 2, 2), 'color': (255, 200, 255)},
{'rect': pygame.Rect(122, 48, 2, 2), 'color': (255, 200, 255)},
{'rect': pygame.Rect(124, 48, 2, 2), 'color': (255, 200, 255)},
{'rect': pygame.Rect(126, 48, 2, 2), 'color': (128, 0, 0)},
{'rect': pygame.Rect(102, 50, 2, 2), 'color': (255, 200, 200)},
{'rect': pygame.Rect(104, 50, 2, 2), 'color': (255, 200, 200)},
{'rect': pygame.Rect(106, 50, 2, 2), 'color': (255, 200, 200)},
{'rect': pygame.Rect(108, 50, 2, 2), 'color': (0, 0, 0)},
{'rect': pygame.Rect(110, 50, 2, 2), 'color': (255, 200, 255)},
{'rect': pygame.Rect(112, 50, 2, 2), 'color': (255, 200, 255)},
{'rect': pygame.Rect(114, 50, 2, 2), 'color': (0, 0, 0)},
{'rect': pygame.Rect(116, 50, 2, 2), 'color': (128, 0, 0)},
{'rect': pygame.Rect(118, 50, 2, 2), 'color': (255, 200, 200)},
{'rect': pygame.Rect(120, 50, 2, 2), 'color': (255, 200, 200)},
{'rect': pygame.Rect(122, 50, 2, 2), 'color': (255, 200, 200)},
{'rect': pygame.Rect(124, 50, 2, 2), 'color': (255, 200, 200)},
{'rect': pygame.Rect(126, 50, 2, 2), 'color': (128, 0, 0)},
{'rect': pygame.Rect(102, 52, 2, 2), 'color': (0, 0, 0)},
{'rect': pygame.Rect(104, 52, 2, 2), 'color': (0, 0, 0)},
{'rect': pygame.Rect(106, 52, 2, 2), 'color': (255, 200, 200)},
{'rect': pygame.Rect(108, 52, 2, 2), 'color': (255, 200, 200)},
{'rect': pygame.Rect(110, 52, 2, 2), 'color': (255, 200, 200)},
{'rect': pygame.Rect(112, 52, 2, 2), 'color': (0, 0, 0)},
{'rect': pygame.Rect(114, 52, 2, 2), 'color': (0, 0, 0)},
{'rect': pygame.Rect(116, 52, 2, 2), 'color': (0, 0, 0)},
{'rect': pygame.Rect(118, 52, 2, 2), 'color': (0, 0, 0)},
{'rect': pygame.Rect(120, 52, 2, 2), 'color': (0, 0, 0)},
{'rect': pygame.Rect(122, 52, 2, 2), 'color': (0, 0, 0)},
{'rect': pygame.Rect(124, 52, 2, 2), 'color': (0, 0, 0)},
{'rect': pygame.Rect(126, 52, 2, 2), 'color': (0, 0, 0)},
{'rect': pygame.Rect(128, 52, 2, 2), 'color': (0, 0, 0)},
{'rect': pygame.Rect(104, 54, 2, 2), 'color': (0, 0, 0)},
{'rect': pygame.Rect(106, 54, 2, 2), 'color': (0, 0, 0)},
{'rect': pygame.Rect(108, 54, 2, 2), 'color': (255, 200, 200)},
{'rect': pygame.Rect(110, 54, 2, 2), 'color': (255, 200, 200)},
{'rect': pygame.Rect(112, 54, 2, 2), 'color': (255, 200, 255)},
{'rect': pygame.Rect(114, 54, 2, 2), 'color': (255, 200, 255)},
{'rect': pygame.Rect(116, 54, 2, 2), 'color': (0, 0, 0)},
{'rect': pygame.Rect(118, 54, 2, 2), 'color': (0, 0, 0)},
{'rect': pygame.Rect(120, 54, 2, 2), 'color': (0, 0, 0)},
{'rect': pygame.Rect(122, 54, 2, 2), 'color': (0, 0, 0)},
{'rect': pygame.Rect(124, 54, 2, 2), 'color': (0, 0, 0)},
{'rect': pygame.Rect(126, 54, 2, 2), 'color': (0, 0, 0)},
{'rect': pygame.Rect(106, 56, 2, 2), 'color': (0, 0, 0)},
{'rect': pygame.Rect(108, 56, 2, 2), 'color': (255, 200, 200)},
{'rect': pygame.Rect(110, 56, 2, 2), 'color': (255, 200, 200)},
{'rect': pygame.Rect(112, 56, 2, 2), 'color': (255, 200, 200)},
{'rect': pygame.Rect(114, 56, 2, 2), 'color': (255, 200, 200)},
{'rect': pygame.Rect(116, 56, 2, 2), 'color': (255, 200, 200)},
{'rect': pygame.Rect(118, 56, 2, 2), 'color': (255, 200, 200)},
{'rect': pygame.Rect(120, 56, 2, 2), 'color': (255, 200, 200)},
{'rect': pygame.Rect(122, 56, 2, 2), 'color': (255, 200, 200)},
{'rect': pygame.Rect(124, 56, 2, 2), 'color': (128, 0, 0)},
{'rect': pygame.Rect(108, 58, 2, 2), 'color': (0, 0, 0)},
{'rect': pygame.Rect(110, 58, 2, 2), 'color': (200, 0, 128)},
{'rect': pygame.Rect(112, 58, 2, 2), 'color': (200, 0, 128)},
{'rect': pygame.Rect(114, 58, 2, 2), 'color': (150, 50, 50)},
{'rect': pygame.Rect(116, 58, 2, 2), 'color': (150, 50, 50)},
{'rect': pygame.Rect(118, 58, 2, 2), 'color': (128, 0, 0)},
{'rect': pygame.Rect(120, 58, 2, 2), 'color': (128, 0, 0)},
{'rect': pygame.Rect(122, 58, 2, 2), 'color': (128, 0, 0)},
{'rect': pygame.Rect(106, 60, 2, 2), 'color': (150, 50, 50)},
{'rect': pygame.Rect(108, 60, 2, 2), 'color': (255, 0, 0)},
{'rect': pygame.Rect(110, 60, 2, 2), 'color': (255, 0, 0)},
{'rect': pygame.Rect(112, 60, 2, 2), 'color': (150, 50, 50)},
{'rect': pygame.Rect(114, 60, 2, 2), 'color': (200, 0, 128)},
{'rect': pygame.Rect(116, 60, 2, 2), 'color': (128, 0, 0)},
{'rect': pygame.Rect(118, 60, 2, 2), 'color': (255, 255, 255)},
{'rect': pygame.Rect(120, 60, 2, 2), 'color': (255, 255, 255)},
{'rect': pygame.Rect(122, 60, 2, 2), 'color': (255, 255, 255)},
{'rect': pygame.Rect(124, 60, 2, 2), 'color': (128, 0, 0)},
{'rect': pygame.Rect(104, 62, 2, 2), 'color': (150, 50, 50)},
{'rect': pygame.Rect(106, 62, 2, 2), 'color': (200, 0, 128)},
{'rect': pygame.Rect(108, 62, 2, 2), 'color': (255, 0, 0)},
{'rect': pygame.Rect(110, 62, 2, 2), 'color': (255, 0, 0)},
{'rect': pygame.Rect(112, 62, 2, 2), 'color': (255, 0, 0)},
{'rect': pygame.Rect(114, 62, 2, 2), 'color': (128, 0, 0)},
{'rect': pygame.Rect(116, 62, 2, 2), 'color': (255, 255, 255)},
{'rect': pygame.Rect(118, 62, 2, 2), 'color': (255, 255, 255)},
{'rect': pygame.Rect(120, 62, 2, 2), 'color': (255, 255, 255)},
{'rect': pygame.Rect(122, 62, 2, 2), 'color': (255, 255, 255)},
{'rect': pygame.Rect(124, 62, 2, 2), 'color': (255, 255, 255)},
{'rect': pygame.Rect(126, 62, 2, 2), 'color': (128, 0, 0)},
{'rect': pygame.Rect(104, 64, 2, 2), 'color': (150, 50, 50)},
{'rect': pygame.Rect(106, 64, 2, 2), 'color': (200, 0, 128)},
{'rect': pygame.Rect(108, 64, 2, 2), 'color': (200, 0, 128)},
{'rect': pygame.Rect(110, 64, 2, 2), 'color': (255, 0, 0)},
{'rect': pygame.Rect(112, 64, 2, 2), 'color': (255, 0, 0)},
{'rect': pygame.Rect(114, 64, 2, 2), 'color': (128, 0, 0)},
{'rect': pygame.Rect(116, 64, 2, 2), 'color': (255, 255, 255)},
{'rect': pygame.Rect(118, 64, 2, 2), 'color': (255, 255, 255)},
{'rect': pygame.Rect(120, 64, 2, 2), 'color': (255, 255, 255)},
{'rect': pygame.Rect(122, 64, 2, 2), 'color': (255, 255, 255)},
{'rect': pygame.Rect(124, 64, 2, 2), 'color': (255, 255, 255)},
{'rect': pygame.Rect(126, 64, 2, 2), 'color': (128, 0, 0)},
{'rect': pygame.Rect(104, 66, 2, 2), 'color': (0, 0, 128)},
{'rect': pygame.Rect(106, 66, 2, 2), 'color': (150, 50, 50)},
{'rect': pygame.Rect(108, 66, 2, 2), 'color': (200, 0, 128)},
{'rect': pygame.Rect(110, 66, 2, 2), 'color': (200, 0, 128)},
{'rect': pygame.Rect(112, 66, 2, 2), 'color': (255, 0, 0)},
{'rect': pygame.Rect(114, 66, 2, 2), 'color': (200, 0, 128)},
{'rect': pygame.Rect(116, 66, 2, 2), 'color': (128, 0, 0)},
{'rect': pygame.Rect(118, 66, 2, 2), 'color': (255, 255, 255)},
{'rect': pygame.Rect(120, 66, 2, 2), 'color': (255, 255, 255)},
{'rect': pygame.Rect(122, 66, 2, 2), 'color': (255, 255, 255)},
{'rect': pygame.Rect(124, 66, 2, 2), 'color': (128, 0, 0)},
{'rect': pygame.Rect(104, 68, 2, 2), 'color': (0, 0, 128)},
{'rect': pygame.Rect(106, 68, 2, 2), 'color': (0, 0, 128)},
{'rect': pygame.Rect(108, 68, 2, 2), 'color': (150, 50, 50)},
{'rect': pygame.Rect(110, 68, 2, 2), 'color': (200, 0, 128)},
{'rect': pygame.Rect(112, 68, 2, 2), 'color': (200, 0, 128)},
{'rect': pygame.Rect(114, 68, 2, 2), 'color': (150, 50, 50)},
{'rect': pygame.Rect(116, 68, 2, 2), 'color': (150, 50, 50)},
{'rect': pygame.Rect(118, 68, 2, 2), 'color': (128, 0, 0)},
{'rect': pygame.Rect(120, 68, 2, 2), 'color': (128, 0, 0)},
{'rect': pygame.Rect(122, 68, 2, 2), 'color': (128, 0, 0)},
{'rect': pygame.Rect(104, 70, 2, 2), 'color': (0, 0, 128)},
{'rect': pygame.Rect(106, 70, 2, 2), 'color': (100, 149, 237)},
{'rect': pygame.Rect(108, 70, 2, 2), 'color': (0, 0, 128)},
{'rect': pygame.Rect(110, 70, 2, 2), 'color': (150, 50, 50)},
{'rect': pygame.Rect(112, 70, 2, 2), 'color': (150, 50, 50)},
{'rect': pygame.Rect(114, 70, 2, 2), 'color': (150, 50, 50)},
{'rect': pygame.Rect(116, 70, 2, 2), 'color': (0, 255, 255)},
{'rect': pygame.Rect(118, 70, 2, 2), 'color': (0, 255, 255)},
{'rect': pygame.Rect(120, 70, 2, 2), 'color': (0, 255, 255)},
{'rect': pygame.Rect(122, 70, 2, 2), 'color': (100, 149, 237)},
{'rect': pygame.Rect(124, 70, 2, 2), 'color': (0, 0, 128)},
{'rect': pygame.Rect(104, 72, 2, 2), 'color': (0, 0, 128)},
{'rect': pygame.Rect(106, 72, 2, 2), 'color': (100, 149, 237)},
{'rect': pygame.Rect(108, 72, 2, 2), 'color': (100, 149, 237)},
{'rect': pygame.Rect(110, 72, 2, 2), 'color': (100, 149, 237)},
{'rect': pygame.Rect(112, 72, 2, 2), 'color': (0, 255, 255)},
{'rect': pygame.Rect(114, 72, 2, 2), 'color': (0, 255, 255)},
{'rect': pygame.Rect(116, 72, 2, 2), 'color': (0, 255, 255)},
{'rect': pygame.Rect(118, 72, 2, 2), 'color': (0, 255, 255)},
{'rect': pygame.Rect(120, 72, 2, 2), 'color': (0, 255, 255)},
{'rect': pygame.Rect(122, 72, 2, 2), 'color': (100, 149, 237)},
{'rect': pygame.Rect(124, 72, 2, 2), 'color': (0, 0, 128)},
{'rect': pygame.Rect(106, 74, 2, 2), 'color': (0, 0, 128)},
{'rect': pygame.Rect(108, 74, 2, 2), 'color': (100, 149, 237)},
{'rect': pygame.Rect(110, 74, 2, 2), 'color': (100, 149, 237)},
{'rect': pygame.Rect(112, 74, 2, 2), 'color': (100, 149, 237)},
{'rect': pygame.Rect(114, 74, 2, 2), 'color': (0, 255, 255)},
{'rect': pygame.Rect(116, 74, 2, 2), 'color': (0, 255, 255)},
{'rect': pygame.Rect(118, 74, 2, 2), 'color': (0, 0, 128)},
{'rect': pygame.Rect(120, 74, 2, 2), 'color': (100, 149, 237)},
{'rect': pygame.Rect(122, 74, 2, 2), 'color': (0, 0, 128)},
{'rect': pygame.Rect(106, 76, 2, 2), 'color': (0, 0, 128)},
{'rect': pygame.Rect(108, 76, 2, 2), 'color': (100, 149, 237)},
{'rect': pygame.Rect(110, 76, 2, 2), 'color': (100, 149, 237)},
{'rect': pygame.Rect(112, 76, 2, 2), 'color': (100, 149, 237)},
{'rect': pygame.Rect(114, 76, 2, 2), 'color': (100, 149, 237)},
{'rect': pygame.Rect(116, 76, 2, 2), 'color': (100, 149, 237)},
{'rect': pygame.Rect(118, 76, 2, 2), 'color': (0, 0, 128)},
{'rect': pygame.Rect(120, 76, 2, 2), 'color': (100, 149, 237)},
{'rect': pygame.Rect(122, 76, 2, 2), 'color': (0, 0, 128)},
{'rect': pygame.Rect(108, 78, 2, 2), 'color': (0, 0, 128)},
{'rect': pygame.Rect(110, 78, 2, 2), 'color': (0, 0, 128)},
{'rect': pygame.Rect(112, 78, 2, 2), 'color': (0, 0, 128)},
{'rect': pygame.Rect(114, 78, 2, 2), 'color': (0, 0, 128)},
{'rect': pygame.Rect(116, 78, 2, 2), 'color': (0, 0, 128)},
{'rect': pygame.Rect(118, 78, 2, 2), 'color': (0, 0, 128)},
{'rect': pygame.Rect(120, 78, 2, 2), 'color': (0, 0, 128)},
{'rect': pygame.Rect(108, 80, 2, 2), 'color': (128, 0, 0)},
{'rect': pygame.Rect(110, 80, 2, 2), 'color': (128, 0, 0)},
{'rect': pygame.Rect(112, 80, 2, 2), 'color': (128, 0, 0)},
{'rect': pygame.Rect(114, 80, 2, 2), 'color': (128, 0, 0)},
{'rect': pygame.Rect(116, 80, 2, 2), 'color': (0, 0, 0)},
{'rect': pygame.Rect(118, 80, 2, 2), 'color': (128, 0, 0)},
{'rect': pygame.Rect(120, 80, 2, 2), 'color': (0, 0, 0)},
{'rect': pygame.Rect(108, 82, 2, 2), 'color': (0, 0, 0)},
{'rect': pygame.Rect(110, 82, 2, 2), 'color': (128, 0, 0)},
{'rect': pygame.Rect(112, 82, 2, 2), 'color': (128, 0, 0)},
{'rect': pygame.Rect(114, 82, 2, 2), 'color': (128, 0, 0)},
{'rect': pygame.Rect(116, 82, 2, 2), 'color': (255, 255, 151)},
{'rect': pygame.Rect(118, 82, 2, 2), 'color': (0, 0, 0)},
{'rect': pygame.Rect(120, 82, 2, 2), 'color': (255, 255, 151)},
{'rect': pygame.Rect(122, 82, 2, 2), 'color': (0, 0, 0)},
{'rect': pygame.Rect(108, 84, 2, 2), 'color': (0, 0, 0)},
{'rect': pygame.Rect(110, 84, 2, 2), 'color': (0, 0, 0)},
{'rect': pygame.Rect(112, 84, 2, 2), 'color': (0, 0, 0)},
{'rect': pygame.Rect(114, 84, 2, 2), 'color': (0, 0, 0)},
{'rect': pygame.Rect(116, 84, 2, 2), 'color': (0, 0, 0)},
{'rect': pygame.Rect(118, 84, 2, 2), 'color': (0, 0, 0)},
{'rect': pygame.Rect(120, 84, 2, 2), 'color': (0, 0, 0)},
{'rect': pygame.Rect(122, 84, 2, 2), 'color': (0, 0, 0)}]
########################
T = [
{'rect':pygame.Rect(102, 552, 2, 2), 'color': (0, 0, 0)},
{'rect':pygame.Rect(102, 554, 2, 2), 'color': (0, 0, 0)},
{'rect':pygame.Rect(102, 556, 2, 2), 'color': (0, 0, 0)},
{'rect':pygame.Rect(102, 558, 2, 2), 'color': (0, 0, 0)},
{'rect':pygame.Rect(102, 560, 2, 2), 'color': (0, 0, 0)},
{'rect':pygame.Rect(102, 562, 2, 2), 'color': (0, 0, 0)},
{'rect':pygame.Rect(102, 564, 2, 2), 'color': (0, 0, 0)},
{'rect':pygame.Rect(102, 566, 2, 2), 'color': (0, 0, 0)},
{'rect':pygame.Rect(102, 568, 2, 2), 'color': (0, 0, 0)},
{'rect':pygame.Rect(102, 570, 2, 2), 'color': (0, 0, 0)},
{'rect':pygame.Rect(104, 550, 2, 2), 'color': (0, 0, 0)},
{'rect':pygame.Rect(104, 552, 2, 2), 'color': (128, 255, 0)},
{'rect':pygame.Rect(104, 554, 2, 2), 'color': (128, 255, 0)},
{'rect':pygame.Rect(104, 556, 2, 2), 'color': (128, 255, 0)},
{'rect':pygame.Rect(104, 558, 2, 2), 'color': (0, 0, 0)},
{'rect':pygame.Rect(104, 560, 2, 2), 'color': (128, 0, 0)},
{'rect':pygame.Rect(104, 562, 2, 2), 'color': (128, 0, 0)},
{'rect':pygame.Rect(104, 564, 2, 2), 'color': (128, 0, 0)},
{'rect':pygame.Rect(104, 566, 2, 2), 'color': (128, 0, 0)},
{'rect':pygame.Rect(104, 568, 2, 2), 'color': (128, 0, 0)},
{'rect':pygame.Rect(106, 550, 2, 2), 'color': (0, 0, 0)},
{'rect':pygame.Rect(106, 552, 2, 2), 'color': (128, 255, 0)},
{'rect':pygame.Rect(106, 554, 2, 2), 'color': (128, 255, 0)},
{'rect':pygame.Rect(106, 556, 2, 2), 'color': (128, 255, 0)},
{'rect':pygame.Rect(106, 558, 2, 2), 'color': (0, 0, 0)},
{'rect':pygame.Rect(106, 560, 2, 2), 'color': (128, 0, 0)},
{'rect':pygame.Rect(106, 562, 2, 2), 'color': (128, 0, 0)},
{'rect':pygame.Rect(106, 564, 2, 2), 'color': (128, 0, 0)},
{'rect':pygame.Rect(106, 566, 2, 2), 'color': (128, 0, 0)},
{'rect':pygame.Rect(106, 568, 2, 2), 'color': (128, 0, 0)},
{'rect':pygame.Rect(108, 550, 2, 2), 'color': (0, 0, 0)},
{'rect':pygame.Rect(108, 552, 2, 2), 'color': (128, 255, 0)},
{'rect':pygame.Rect(108, 554, 2, 2), 'color': (128, 255, 0)},
{'rect':pygame.Rect(108, 556, 2, 2), 'color': (128, 255, 0)},
{'rect':pygame.Rect(108, 558, 2, 2), 'color': (0, 0, 0)},
{'rect':pygame.Rect(108, 560, 2, 2), 'color': (128, 0, 0)},
{'rect':pygame.Rect(108, 562, 2, 2), 'color': (128, 0, 0)},
{'rect':pygame.Rect(108, 564, 2, 2), 'color': (128, 0, 0)},
{'rect':pygame.Rect(108, 566, 2, 2), 'color': (128, 0, 0)},
{'rect':pygame.Rect(108, 568, 2, 2), 'color': (128, 0, 0)},
{'rect':pygame.Rect(110, 550, 2, 2), 'color': (0, 0, 0)},
{'rect':pygame.Rect(110, 552, 2, 2), 'color': (128, 255, 0)},
{'rect':pygame.Rect(110, 554, 2, 2), 'color': (128, 255, 0)},
{'rect':pygame.Rect(110, 556, 2, 2), 'color': (128, 255, 0)},
{'rect':pygame.Rect(110, 558, 2, 2), 'color': (128, 255, 0)},
{'rect':pygame.Rect(110, 560, 2, 2), 'color': (0, 0, 0)},
{'rect':pygame.Rect(110, 562, 2, 2), 'color': (128, 0, 0)},
{'rect':pygame.Rect(110, 564, 2, 2), 'color': (128, 0, 0)},
{'rect':pygame.Rect(110, 566, 2, 2), 'color': (128, 0, 0)},
{'rect':pygame.Rect(110, 568, 2, 2), 'color': (128, 0, 0)},
{'rect':pygame.Rect(110, 570, 2, 2), 'color': (128, 0, 0)},
{'rect':pygame.Rect(112, 550, 2, 2), 'color': (0, 0, 0)},
{'rect':pygame.Rect(112, 552, 2, 2), 'color': (128, 255, 0)},
{'rect':pygame.Rect(112, 554, 2, 2), 'color': (128, 255, 0)},
{'rect':pygame.Rect(112, 556, 2, 2), 'color': (128, 255, 0)},
{'rect':pygame.Rect(112, 558, 2, 2), 'color': (128, 255, 0)},
{'rect':pygame.Rect(112, 560, 2, 2), 'color': (128, 255, 0)},
{'rect':pygame.Rect(112, 562, 2, 2), 'color': (0, 0, 0)},
{'rect':pygame.Rect(112, 564, 2, 2), 'color': (128, 0, 0)},
{'rect':pygame.Rect(112, 566, 2, 2), 'color': (128, 0, 0)},
{'rect':pygame.Rect(112, 568, 2, 2), 'color': (128, 0, 0)},
{'rect':pygame.Rect(112, 570, 2, 2), 'color': (128, 0, 0)},
{'rect':pygame.Rect(112, 572, 2, 2), 'color': (128, 0, 0)},
{'rect':pygame.Rect(114, 550, 2, 2), 'color': (0, 0, 0)},
{'rect':pygame.Rect(114, 552, 2, 2), 'color': (128, 255, 0)},
{'rect':pygame.Rect(114, 554, 2, 2), 'color': (128, 255, 0)},
{'rect':pygame.Rect(114, 556, 2, 2), 'color': (128, 255, 0)},
{'rect':pygame.Rect(114, 558, 2, 2), 'color': (128, 255, 0)},
{'rect':pygame.Rect(114, 560, 2, 2), 'color': (128, 255, 0)},
{'rect':pygame.Rect(114, 562, 2, 2), 'color': (128, 255, 0)},
{'rect':pygame.Rect(114, 564, 2, 2), 'color': (0, 0, 0)},
{'rect':pygame.Rect(114, 566, 2, 2), 'color': (128, 0, 0)},
{'rect':pygame.Rect(114, 568, 2, 2), 'color': (128, 0, 0)},
{'rect':pygame.Rect(114, 570, 2, 2), 'color': (128, 0, 0)},
{'rect':pygame.Rect(114, 572, 2, 2), 'color': (128, 0, 0)},
{'rect':pygame.Rect(114, 574, 2, 2), 'color': (128, 0, 0)},
{'rect':pygame.Rect(116, 550, 2, 2), 'color': (0, 0, 0)},
{'rect':pygame.Rect(116, 552, 2, 2), 'color': (128, 255, 0)},
{'rect':pygame.Rect(116, 554, 2, 2), 'color': (128, 255, 0)},
{'rect':pygame.Rect(116, 556, 2, 2), 'color': (128, 255, 0)},
{'rect':pygame.Rect(116, 558, 2, 2), 'color': (128, 255, 0)},
{'rect':pygame.Rect(116, 560, 2, 2), 'color': (128, 255, 0)},
{'rect':pygame.Rect(116, 562, 2, 2), 'color': (128, 255, 0)},
{'rect':pygame.Rect(116, 564, 2, 2), 'color': (0, 0, 0)},
{'rect':pygame.Rect(116, 566, 2, 2), 'color': (128, 0, 0)},
{'rect':pygame.Rect(116, 568, 2, 2), 'color': (128, 0, 0)},
{'rect':pygame.Rect(116, 570, 2, 2), 'color': (128, 0, 0)},
{'rect':pygame.Rect(116, 572, 2, 2), 'color': (128, 0, 0)},
{'rect':pygame.Rect(116, 574, 2, 2), 'color': (128, 0, 0)},
{'rect':pygame.Rect(118, 550, 2, 2), 'color': (0, 0, 0)},
{'rect':pygame.Rect(118, 552, 2, 2), 'color': (128, 255, 0)},
{'rect':pygame.Rect(118, 554, 2, 2), 'color': (128, 255, 0)},
{'rect':pygame.Rect(118, 556, 2, 2), 'color': (128, 255, 0)},
{'rect':pygame.Rect(118, 558, 2, 2), 'color': (128, 255, 0)},
{'rect':pygame.Rect(118, 560, 2, 2), 'color': (128, 255, 0)},
{'rect':pygame.Rect(118, 562, 2, 2), 'color': (128, 255, 0)},
{'rect':pygame.Rect(118, 564, 2, 2), 'color': (0, 0, 0)},
{'rect':pygame.Rect(118, 566, 2, 2), 'color': (128, 0, 0)},
{'rect':pygame.Rect(118, 568, 2, 2), 'color': (128, 0, 0)},
{'rect':pygame.Rect(118, 570, 2, 2), 'color': (128, 0, 0)},
{'rect':pygame.Rect(118, 572, 2, 2), 'color': (128, 0, 0)},
{'rect':pygame.Rect(118, 574, 2, 2), 'color': (128, 0, 0)},
{'rect':pygame.Rect(120, 550, 2, 2), 'color': (0, 0, 0)},
{'rect':pygame.Rect(120, 552, 2, 2), 'color': (128, 255, 0)},
{'rect':pygame.Rect(120, 554, 2, 2), 'color': (128, 255, 0)},
{'rect':pygame.Rect(120, 556, 2, 2), 'color': (128, 255, 0)},
{'rect':pygame.Rect(120, 558, 2, 2), 'color': (128, 255, 0)},
{'rect':pygame.Rect(120, 560, 2, 2), 'color': (128, 255, 0)},
{'rect':pygame.Rect(120, 562, 2, 2), 'color': (0, 0, 0)},
{'rect':pygame.Rect(120, 564, 2, 2), 'color': (128, 0, 0)},
{'rect':pygame.Rect(120, 566, 2, 2), 'color': (128, 0, 0)},
{'rect':pygame.Rect(120, 568, 2, 2), 'color': (128, 0, 0)},
{'rect':pygame.Rect(120, 570, 2, 2), 'color': (128, 0, 0)},
{'rect':pygame.Rect(120, 572, 2, 2), 'color': (128, 0, 0)},
{'rect':pygame.Rect(122, 550, 2, 2), 'color': (0, 0, 0)},
{'rect':pygame.Rect(122, 552, 2, 2), 'color': (128, 255, 0)},
{'rect':pygame.Rect(122, 554, 2, 2), 'color': (128, 255, 0)},
{'rect':pygame.Rect(122, 556, 2, 2), 'color': (128, 255, 0)},
{'rect':pygame.Rect(122, 558, 2, 2), 'color': (128, 255, 0)},
{'rect':pygame.Rect(122, 560, 2, 2), 'color': (0, 0, 0)},
{'rect':pygame.Rect(122, 562, 2, 2), 'color': (128, 0, 0)},
{'rect':pygame.Rect(122, 564, 2, 2), 'color': (128, 0, 0)},
{'rect':pygame.Rect(122, 566, 2, 2), 'color': (128, 0, 0)},
{'rect':pygame.Rect(122, 568, 2, 2), 'color': (128, 0, 0)},
{'rect':pygame.Rect(122, 570, 2, 2), 'color': (128, 0, 0)},
{'rect':pygame.Rect(124, 552, 2, 2), 'color': (0, 0, 0)},
{'rect':pygame.Rect(124, 554, 2, 2), 'color': (0, 0, 0)},
{'rect':pygame.Rect(124, 556, 2, 2), 'color': (0, 0, 0)},
{'rect':pygame.Rect(124, 558, 2, 2), 'color': (0, 0, 0)},
{'rect':pygame.Rect(124, 560, 2, 2), 'color': (0, 0, 0)},
{'rect':pygame.Rect(124, 562, 2, 2), 'color': (0, 0, 0)},
{'rect':pygame.Rect(124, 564, 2, 2), 'color': (0, 0, 0)},
{'rect':pygame.Rect(124, 566, 2, 2), 'color': (0, 0, 0)},
{'rect':pygame.Rect(124, 568, 2, 2), 'color': (0, 0, 0)},
{'rect':pygame.Rect(124, 570, 2, 2), 'color': (0, 0, 0)}]
########################

def jogo():
    jogando = True
    solo = 500
    pos_x = 0
    pos_y = solo - 36
    t  = 2
    
    for i in range(len(M)): 
        M[i]["rect"] = [M[i]['rect'][0] + pos_x, M[i]['rect'][1] + pos_y, t, t]
    
    while jogando:
        for event in pygame.event.get():
            if event.type == pygame.QUIT:
                jogando = False
        
        px = 0
        py = 0
        p = True 
        veloc0 = 10
        
        # Movimentos:
        comandos = pygame.key.get_pressed()
        if M[294]['rect'][1] - t >= solo + 46: p = True
        else: p = False    
            
        if comandos[pygame.K_UP] and p: py -= 8*veloc0       
        if comandos[pygame.K_LEFT]  and M[294]['rect'][0] > 30   : px -= veloc0
        if comandos[pygame.K_RIGHT] and M[294]['rect'][0] < 1090 : px += veloc0         
                
        # Atualização de Posições e Imagem:
        windowSurface.fill(branco)
        
        for i in range(len(M)):
            M[i]["rect"] = [M[i]['rect'][0] + px, M[i]['rect'][1] + py, t, t]
            # Gravidade:
            if 2>1:
                M[i]["rect"] = [M[i]['rect'][0], M[i]['rect'][1] + 5, t, t]  
                
        if M[287]['rect'][1] >= solo + 50:
            for i in range(len(M)):
                    M[i]["rect"] = [M[i]['rect'][0], M[i]['rect'][1] - 5, t, t]
                         
        for i in range(len(M)): pygame.draw.rect(windowSurface, M[i]["color"], M[i]["rect"])
        for i in range(len(T)): pygame.draw.rect(windowSurface, T[i]["color"], T[i]["rect"])  
        
        # Regulando o tempo e atualizando a tela:
        relogio.tick(50)
        pygame.display.update()  

jogo()
pygame.quit()
# Out:
# pygame 1.9.6
# Hello from the pygame community. https://www.pygame.org/contribute.html

# %%
import pygame, time
from pygame.locals import *
from random import randint

pygame.init()

largura = 780 
altura  = 600

janela = pygame.display.set_mode((780, 600))
pygame.display.set_caption('Barrel')

def jogo():
    
    sair = True
    fimdejogo = False
    
    pygame.time.delay(60)     # dá um delay necessário para vermos o desenho;  

    # posição no eixo x e no eixo y;
    pos_y0 = altura - 130                     
    pos_x0 = 50                                          

    pos_x1 = 600
    pos_y1 = 20       
    
    velocB = 20 
    veloc1 = 5
    veloc2 = 30
    
    descendo = True
    l = 1
    
    fundo = pygame.image.load('ha.PNG')

    b1 = pygame.image.load('DK.PNG')
    b2 = pygame.image.load('DK - Copia.PNG')
    bonec = b1

    f1 = pygame.image.load('crashed.png')
    
    while sair:
                              
        for event in pygame.event.get():
            if event.type == pygame.QUIT:
                sair = False
        
        # Gravidade:
        if pos_y0 < altura - 130:
            pos_y0 += velocB
            
        # movimentos e limitações;    
        comandos = pygame.key.get_pressed()
        
        if comandos[pygame.K_UP] and pos_y0 > 400:      # jump
                pos_y0 -= 3*velocB
             
        if comandos[pygame.K_LEFT] and pos_x0 > 0:
                bonec = b2
                pos_x0 -= velocB
                
        if comandos[pygame.K_RIGHT] and pos_x0 < 680:
                bonec = b1
                pos_x0 += velocB   
                
        # Movimentação:
       
        # Lugar de descida 1: ######################################3
        if l == 1:         
            # descendo:
            if pos_y1 <= 300 and descendo == True: 
                pos_y1 += veloc2
            else:
                descendo = False
            
            # subindo:
            if pos_y1 >= 20 and descendo == False: 
                pos_y1 -= veloc1
                if pos_y1 <= 20:     # se if pos_y1 >= 100: o barril desce, muda de lugar por baixo e sobe;
                    l += 1
                    descendo = True
           #else:
               #descendo = True       # se fizermos isso, o barril sobe e desce sem parar;         
        
        # Lugar de descida 2: ######################################3
        if (l == 2) and (pos_x1 > 320):
            pos_x1 -= veloc1
        
        if (l == 2) and (pos_x1 <= 320):
            # descendo:
            if pos_y1 <= 300 and descendo == True: 
                pos_y1 += veloc2
            else:
                descendo = False
            
            # subindo:
            if pos_y1 >= 20 and descendo == False: 
                pos_y1 -= veloc1
                if pos_y1 <= 20:
                    l += 1
                    descendo = True
#            else:
#                l = 2
            #     descendo = True
            
        # Lugar de descida 3: ######################################3
        if (l == 3) and pos_x1 > 50:
            pos_x1 -= veloc1
        
        if(l == 3) and (pos_x1 <= 50):
            # descendo:
            if pos_y1 <= 300 and descendo == True: 
                pos_y1 += veloc2
            else:
                descendo = False
            
            # subindo:
            if pos_y1 >= 20 and descendo == False: 
                pos_y1 -= veloc1
                if pos_y1 <= 20:
                    l += 1
#            else:
#                l = 3                  
            #     descendo = True  
        
        # Voltando ao lugar de descida 1: 
        if (l == 4):
            pos_x1 += veloc1
            if pos_x1 >= largura - 200:
                l -= 3
                descendo = True
        
        
        # invocação das figuras;        
        janela.blit(fundo, (0, 0))
        janela.blit(bonec, (pos_x0, pos_y0))        
        janela.blit(f1, (pos_x1, pos_y1))
                   
        pygame.display.update()                                    # atualiza a tela

jogo()        
pygame.quit()

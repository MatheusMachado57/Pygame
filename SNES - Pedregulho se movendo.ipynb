# %%
import pygame, sys, time
from pygame.locals import *

# set up pygame
pygame.init()

# set up the window
largura = 400
altura  = 600
windowSurface = pygame.display.set_mode((largura, altura), 0, 32)

branco    = (255,255,255)
cinza     = (127,127,127)
verde     = (0,255,0)
vermesc   = (127,0,0)
rosa      = (255,200,200)
preto     = (0,0,0)
amarelo   = (255,255,0)
amarclar  = (255,255,151)
tamanho   = 10

pygame.display.set_caption("Pedra")

def building(saindo, tam_pix, pos_x, pos_y):  
        sair = True
    
        if saindo == True:
            for event in pygame.event.get():
                if event.type == pygame.QUIT:
                    sair = False  
              
        # PEDRA:
        ## 1 HHORIZONTAL:
        l = []
        a = []
        px = pos_x
        py = pos_y
        t = tam_pix
        
        ### 1 parte:
        q1 = 6
        for i in range(q1):
            b = {"rect":pygame.Rect(px, py, t, t), "color":preto}
            a.append(b)
            l.append([px,py])
            px += t
                 
        ### 2 parte:  
        q2 = q1 + 1
        for i in range(q1,q2):
            b = {"rect":pygame.Rect(px, py, t, t), "color":branco}
            a.append(b)
            l.append([px,py])
            px += t
                       
        ### 3 parte:
        q3 = q2 + 5
        for i in range(q2,q3):
            b = {"rect":pygame.Rect(px, py, t, t), "color":preto}
            a.append(b)
            l.append([px,py])
            px += t
                  
        ### 4 parte:
        q4 = q3 + 1
        for i in range(q3,q4):
            b = {"rect":pygame.Rect(px, py, t, t), "color":branco}
            a.append(b)
            l.append([px,py])
            px += t
               
        ### 5 parte:
        q5 = q4 + 5
        for i in range(q4,q5):
            b = {"rect":pygame.Rect(px, py, t, t), "color":preto}
            a.append(b)
            l.append([px,py])
            px += t
                  
        ### 6 parte:
        q6 = q5 + 1
        for i in range(q5,q6):
            b = {"rect":pygame.Rect(px, py, t, t), "color":branco}
            a.append(b)
            l.append([px,py])
            px += t
              
        ### 7 parte:
        q7 = q6 + 6
        for i in range(q6,q7):
            b = {"rect":pygame.Rect(px, py, t, t), "color":preto}
            a.append(b)
            l.append([px,py])
            px += t
                          
        ## 2 HORIZONTAL:
        px = pos_x
        py = py + t
        
        ### 1 parte:
        q1 = 1
        for i in range(q1):
            b = {"rect":pygame.Rect(px, py, t, t), "color":preto}
            a.append(b)
            l.append([px,py])
            px += t
                  
        ### 2 parte:  
        q2 = q1 + 4
        for i in range(q1,q2):
            b = {"rect":pygame.Rect(px, py, t, t), "color":cinza}
            a.append(b)
            l.append([px,py])
            px += t
                      
        ### 3 parte:
        q3 = q2 + 2
        for i in range(q2,q3):
            b = {"rect":pygame.Rect(px, py, t, t), "color":preto}
            a.append(b)
            l.append([px,py])
            px += t
                   
        ### 4 parte:  
        q4 = q3 + 4
        for i in range(q3,q4):
            b = {"rect":pygame.Rect(px, py, t, t), "color":cinza}
            a.append(b)
            l.append([px,py])
            px += t
                      
        ### 5 parte:
        q5 = q4 + 3
        for i in range(q4,q5):
            b = {"rect":pygame.Rect(px, py, t, t), "color":preto}
            a.append(b)
            l.append([px,py])
            px += t
                          
        ### 6 parte:  
        q6 = q5 + 4
        for i in range(q5,q6):
            b = {"rect":pygame.Rect(px, py, t, t), "color":cinza}
            a.append(b)
            l.append([px,py])
            px += t
                      
        ### 7 parte:
        q7 = q6 + 2
        for i in range(q6,q7):
            b = {"rect":pygame.Rect(px, py, t, t), "color":preto}
            a.append(b)
            l.append([px,py])
            px += t
                  
        ### 8 parte:  
        q8 = q7 + 4
        for i in range(q7,q8):
            b = {"rect":pygame.Rect(px, py, t, t), "color":cinza}
            a.append(b)
            l.append([px,py])
            px += t
        
        for i in range(q7,q8):
             pygame.draw.rect(windowSurface, a[i]["color"], a[i]["rect"])  
        
        ### 9 parte:  
        q9 = q8 + 1
        for i in range(q8,q9):
            b = {"rect":pygame.Rect(px, py, t, t), "color":preto}
            a.append(b)
            l.append([px,py])
            px += t
                      
        # 3, 4 e 5 Horizontais:   
        for i in range(3):
            
            px = pos_x
            py = py + t
        
            ### 1 parte:
            q1 = 1
            for i in range(q1):
                b = {"rect":pygame.Rect(px, py, t, t), "color":preto}
                a.append(b)
                l.append([px,py])
                px += t
                   
                ### 2 parte:  
                q2 = q1 + 5
                for i in range(q1,q2):
                    b = {"rect":pygame.Rect(px, py, t, t), "color":cinza}
                    a.append(b)
                    l.append([px,py])
                    px += t
                      
            ### 3 parte:
            q3 = q2 + 1
            for i in range(q2,q3):
                b = {"rect":pygame.Rect(px, py, t, t), "color":preto}
                a.append(b)
                l.append([px,py])
                px += t
                   
            ### 4 parte:  
            q4 = q3 + 5
            for i in range(q3,q4):
                b = {"rect":pygame.Rect(px, py, t, t), "color":cinza}
                a.append(b)
                l.append([px,py])
                px += t
                       
            ### 5 parte: 
            q5 = q4 + 1
            for i in range(q4,q5):
                b = {"rect":pygame.Rect(px, py, t, t), "color":preto}
                a.append(b)
                l.append([px,py])
                px += t
                              
            ### 6 parte:  
            q6 = q5 + 5
            for i in range(q5,q6):
                b = {"rect":pygame.Rect(px, py, t, t), "color":cinza}
                a.append(b)
                l.append([px,py])
                px += t
                      
            ### 7 parte:
            q7 = q6 + 1
            for i in range(q6,q7):
                b = {"rect":pygame.Rect(px, py, t, t), "color":preto}
                a.append(b)
                l.append([px,py])
                px += t
                  
            ### 8 parte:  
            q8 = q7 + 5
            for i in range(q7,q8):
                b = {"rect":pygame.Rect(px, py, t, t), "color":cinza}
                a.append(b)
                l.append([px,py])
                px += t
             
            ### 9 parte:  
            q9 = q8 + 1
            for i in range(q8,q9):
                b = {"rect":pygame.Rect(px, py, t, t), "color":preto}
                a.append(b)
                l.append([px,py])
                px += t
              
        ## 6 HORIZONTAL:
        px = pos_x
        py = py + t
        
        ### 1 parte:
        q1 = 1
        for i in range(q1):
            b = {"rect":pygame.Rect(px, py, t, t), "color":branco}
            a.append(b)
            l.append([px,py])
            px += t
        
        ### 2 parte:
        q2 = q1 + 23
        for i in range(q1,q2):
            b = {"rect":pygame.Rect(px, py, t, t), "color":preto}
            a.append(b)
            l.append([px,py])
            px += t
        
        ### 3 parte:
        q3 = q2 + 1
        for i in range(q2,q3):
            b = {"rect":pygame.Rect(px, py, t, t), "color":branco}
            a.append(b)
            l.append([px,py])
            px += t
        
        # 7, 8, 9, 10 Horizontal:          
        for i in range(4):
            px = pos_x
            py = py + t
        
            ### 1 parte:
            q1 = 1
            for i in range(q1):
                b = {"rect":pygame.Rect(px, py, t, t), "color":preto}
                a.append(b)
                l.append([px,py])
                px += t
        
            ### 2 parte:
            q2 = q1 + 5
            for i in range(q1,q2):
                b = {"rect":pygame.Rect(px, py, t, t), "color":cinza}
                a.append(b)
                l.append([px,py])
                px += t
        
            ### 3 parte:
            q3 = q2 + 1
            for i in range(q2,q3):
                b = {"rect":pygame.Rect(px, py, t, t), "color":preto}
                a.append(b)
                l.append([px,py])
                px += t
            
            ### 4 parte:
            q4 = q3 + 11
            for i in range(q3,q4):
                b = {"rect":pygame.Rect(px, py, t, t), "color":cinza}
                a.append(b)
                l.append([px,py])
                px += t
                
            ### 5 parte:
            q5 = q4 + 1
            for i in range(q4,q5):
                b = {"rect":pygame.Rect(px, py, t, t), "color":preto}
                a.append(b)
                l.append([px,py])
                px += t    
                
            ### 6 parte:
            q6 = q5 + 5
            for i in range(q5,q6):
                b = {"rect":pygame.Rect(px, py, t, t), "color":cinza}
                a.append(b)
                l.append([px,py])
                px += t    
                
            ### 7 parte:
            q7 = q6 + 1
            for i in range(q6,q7):
                b = {"rect":pygame.Rect(px, py, t, t), "color":preto}
                a.append(b)
                l.append([px,py])
                px += t    
                
        ### 11 HORIZONTAL:        
        px = pos_x
        py = py + t
        
        ### 1 parte:
        q1 = 1
        for i in range(q1):
            b = {"rect":pygame.Rect(px, py, t, t), "color":branco}
            a.append(b)
            l.append([px,py])
            px += t
        
        q2 = q1 + 6
        for i in range(q1,q2):
            b = {"rect":pygame.Rect(px, py, t, t), "color":preto}
            a.append(b)
            l.append([px,py])
            px += t
            
        q3 = q2 + 11
        for i in range(q2,q3):
            b = {"rect":pygame.Rect(px, py, t, t), "color":cinza}
            a.append(b)
            l.append([px,py])
            px += t
            
        q4 = q3 + 6
        for i in range(q3,q4):
            b = {"rect":pygame.Rect(px, py, t, t), "color":preto}
            a.append(b)
            l.append([px,py])
            px += t   
            
        q5 = q4 + 1
        for i in range(q4,q5):
            b = {"rect":pygame.Rect(px, py, t, t), "color":branco}
            a.append(b)
            l.append([px,py])
            px += t    
        
        ## 12, 13, 14, 15 HORIZONTAL:         
        for i in range(4):
            px = pos_x
            py = py + t
        
            ### 1 parte:
            q1 = 1
            for i in range(q1):
                b = {"rect":pygame.Rect(px, py, t, t), "color":preto}
                a.append(b)
                l.append([px,py])
                px += t
        
            ### 2 parte:
            q2 = q1 + 5
            for i in range(q1,q2):
                b = {"rect":pygame.Rect(px, py, t, t), "color":cinza}
                a.append(b)
                l.append([px,py])
                px += t
        
            ### 3 parte:
            q3 = q2 + 1
            for i in range(q2,q3):
                b = {"rect":pygame.Rect(px, py, t, t), "color":preto}
                a.append(b)
                l.append([px,py])
                px += t
            
            ### 4 parte:
            q4 = q3 + 11
            for i in range(q3,q4):
                b = {"rect":pygame.Rect(px, py, t, t), "color":cinza}
                a.append(b)
                l.append([px,py])
                px += t
                
            ### 5 parte:
            q5 = q4 + 1
            for i in range(q4,q5):
                b = {"rect":pygame.Rect(px, py, t, t), "color":preto}
                a.append(b)
                l.append([px,py])
                px += t    
                
            ### 6 parte:
            q6 = q5 + 5
            for i in range(q5,q6):
                b = {"rect":pygame.Rect(px, py, t, t), "color":cinza}
                a.append(b)
                l.append([px,py])
                px += t    
                
            ### 7 parte:
            q7 = q6 + 1
            for i in range(q6,q7):
                b = {"rect":pygame.Rect(px, py, t, t), "color":preto}
                a.append(b)
                l.append([px,py])
                px += t    
        
        ### 16 HORIZONTAL:        
        px = pos_x
        py = py + t
        
        ### 1 parte:
        q1 = 1
        for i in range(q1):
            b = {"rect":pygame.Rect(px, py, t, t), "color":branco}
            a.append(b)
            l.append([px,py])
            px += t
        
        q2 = q1 + 6
        for i in range(q1,q2):
            b = {"rect":pygame.Rect(px, py, t, t), "color":preto}
            a.append(b)
            l.append([px,py])
            px += t
            
        q3 = q2 + 11
        for i in range(q2,q3):
            b = {"rect":pygame.Rect(px, py, t, t), "color":cinza}
            a.append(b)
            l.append([px,py])
            px += t
            
        q4 = q3 + 6
        for i in range(q3,q4):
            b = {"rect":pygame.Rect(px, py, t, t), "color":preto}
            a.append(b)
            l.append([px,py])
            px += t   
            
        q5 = q4 + 1
        for i in range(q4,q5):
            b = {"rect":pygame.Rect(px, py, t, t), "color":branco}
            a.append(b)
            l.append([px,py])
            px += t    
        
        ## 17, 18, 19, 20 HORIZONTAL:         
        for i in range(4):
            px = pos_x
            py = py + t
        
            ### 1 parte:
            q1 = 1
            for i in range(q1):
                b = {"rect":pygame.Rect(px, py, t, t), "color":preto}
                a.append(b)
                l.append([px,py])
                px += t
        
            ### 2 parte:
            q2 = q1 + 5
            for i in range(q1,q2):
                b = {"rect":pygame.Rect(px, py, t, t), "color":cinza}
                a.append(b)
                l.append([px,py])
                px += t
        
            ### 3 parte:
            q3 = q2 + 1
            for i in range(q2,q3):
                b = {"rect":pygame.Rect(px, py, t, t), "color":preto}
                a.append(b)
                l.append([px,py])
                px += t
            
            ### 4 parte:
            q4 = q3 + 11
            for i in range(q3,q4):
                b = {"rect":pygame.Rect(px, py, t, t), "color":cinza}
                a.append(b)
                l.append([px,py])
                px += t
                
            ### 5 parte:
            q5 = q4 + 1
            for i in range(q4,q5):
                b = {"rect":pygame.Rect(px, py, t, t), "color":preto}
                a.append(b)
                l.append([px,py])
                px += t    
                
            ### 6 parte:
            q6 = q5 + 5
            for i in range(q5,q6):
                b = {"rect":pygame.Rect(px, py, t, t), "color":cinza}
                a.append(b)
                l.append([px,py])
                px += t    
                
            ### 7 parte:
            q7 = q6 + 1
            for i in range(q6,q7):
                b = {"rect":pygame.Rect(px, py, t, t), "color":preto}
                a.append(b)
                l.append([px,py])
                px += t    
        
        ### 21 HORIZONTAL:        
        px = pos_x
        py = py + t
        
        ### 1 parte:
        q1 = 1
        for i in range(q1):
            b = {"rect":pygame.Rect(px, py, t, t), "color":branco}
            a.append(b)
            l.append([px,py])
            px += t
        
        ### 2 parte:
        q2 = q1 + 23
        for i in range(q1,q2):
            b = {"rect":pygame.Rect(px, py, t, t), "color":preto}
            a.append(b)
            l.append([px,py])
            px += t
        
        ### 3 parte:
        q3 = q2 + 1
        for i in range(q2,q3):
            b = {"rect":pygame.Rect(px, py, t, t), "color":branco}
            a.append(b)
            l.append([px,py])
            px += t
            
        # 22, 23 e 24 Horizontais:   
        for i in range(3):
            px = pos_x
            py = py + t
        
            ### 1 parte:
            q1 = 1
            for i in range(q1):
                b = {"rect":pygame.Rect(px, py, t, t), "color":preto}
                a.append(b)
                l.append([px,py])
                px += t
                  
            ### 2 parte:  
            q2 = q1 + 5
            for i in range(q1,q2):
                b = {"rect":pygame.Rect(px, py, t, t), "color":cinza}
                a.append(b)
                l.append([px,py])
                px += t
                       
            ### 3 parte:
            q3 = q2 + 1
            for i in range(q2,q3):
                b = {"rect":pygame.Rect(px, py, t, t), "color":preto}
                a.append(b)
                l.append([px,py])
                px += t
                  
            ### 4 parte:  
            q4 = q3 + 5
            for i in range(q3,q4):
                b = {"rect":pygame.Rect(px, py, t, t), "color":cinza}
                a.append(b)
                l.append([px,py])
                px += t
                      
            ### 5 parte: 
            q5 = q4 + 1
            for i in range(q4,q5):
                b = {"rect":pygame.Rect(px, py, t, t), "color":preto}
                a.append(b)
                l.append([px,py])
                px += t
                              
            ### 6 parte:  
            q6 = q5 + 5
            for i in range(q5,q6):
                b = {"rect":pygame.Rect(px, py, t, t), "color":cinza}
                a.append(b)
                l.append([px,py])
                px += t
                     
            ### 7 parte:
            q7 = q6 + 1
            for i in range(q6,q7):
                b = {"rect":pygame.Rect(px, py, t, t), "color":preto}
                a.append(b)
                l.append([px,py])
                px += t
                  
            ### 8 parte:  
            q8 = q7 + 5
            for i in range(q7,q8):
                b = {"rect":pygame.Rect(px, py, t, t), "color":cinza}
                a.append(b)
                l.append([px,py])
                px += t
             
            ### 9 parte:  
            q9 = q8 + 1
            for i in range(q8,q9):
                b = {"rect":pygame.Rect(px, py, t, t), "color":preto}
                a.append(b)
                l.append([px,py])
                px += t    
                
        ## 25 HORIZONTAL:
        px = pos_x
        py = py + t
                
        ### 1 parte:
        q1 = 1
        for i in range(q1):
            b = {"rect":pygame.Rect(px, py, t, t), "color":preto}
            a.append(b)
            l.append([px,py])
            px += t
                  
        ### 2 parte:  
        q2 = q1 + 4
        for i in range(q1,q2):
            b = {"rect":pygame.Rect(px, py, t, t), "color":cinza}
            a.append(b)
            l.append([px,py])
            px += t
                     
        ### 3 parte:
        q3 = q2 + 2
        for i in range(q2,q3):
            b = {"rect":pygame.Rect(px, py, t, t), "color":preto}
            a.append(b)
            l.append([px,py])
            px += t
                  
        ### 4 parte:  
        q4 = q3 + 4
        for i in range(q3,q4):
            b = {"rect":pygame.Rect(px, py, t, t), "color":cinza}
            a.append(b)
            l.append([px,py])
            px += t
                     
        ### 5 parte: 
        q5 = q4 + 3
        for i in range(q4,q5):
            b = {"rect":pygame.Rect(px, py, t, t), "color":preto}
            a.append(b)
            l.append([px,py])
            px += t
                         
        ### 6 parte:  
        q6 = q5 + 4
        for i in range(q5,q6):
            b = {"rect":pygame.Rect(px, py, t, t), "color":cinza}
            a.append(b)
            l.append([px,py])
            px += t
                      
        ### 7 parte:
        q7 = q6 + 2
        for i in range(q6,q7):
            b = {"rect":pygame.Rect(px, py, t, t), "color":preto}
            a.append(b)
            l.append([px,py])
            px += t
        
        ### 8 parte:  
        q8 = q7 + 4
        for i in range(q7,q8):
            b = {"rect":pygame.Rect(px, py, t, t), "color":cinza}
            a.append(b)
            l.append([px,py])
            px += t
        
        for i in range(q7,q8):
             pygame.draw.rect(windowSurface, a[i]["color"], a[i]["rect"])  
        
        ### 9 parte:  
        q9 = q8 + 1
        for i in range(q8,q9):
            b = {"rect":pygame.Rect(px, py, t, t), "color":preto}
            a.append(b)
            l.append([px,py])
            px += t        
            
        ## 26 HORIZONTAL:
        px = pos_x
        py = py + t    
            
        ### 1 parte:
        q1 = 6
        for i in range(q1):
            b = {"rect":pygame.Rect(px, py, t, t), "color":preto}
            a.append(b)
            l.append([px,py])
            px += t
        
        ### 2 parte:  
        q2 = q1 + 1
        for i in range(q1,q2):
            b = {"rect":pygame.Rect(px, py, t, t), "color":branco}
            a.append(b)
            l.append([px,py])
            px += t
                     
        ### 3 parte:
        q3 = q2 + 5
        for i in range(q2,q3):
            b = {"rect":pygame.Rect(px, py, t, t), "color":preto}
            a.append(b)
            l.append([px,py])
            px += t
                
        ### 4 parte: 
        q4 = q3 + 1
        for i in range(q3,q4):
            b = {"rect":pygame.Rect(px, py, t, t), "color":branco}
            a.append(b)
            l.append([px,py])
            px += t
            
        ### 5 parte:
        q5 = q4 + 5
        for i in range(q4,q5):
            b = {"rect":pygame.Rect(px, py, t, t), "color":preto}
            a.append(b)
            l.append([px,py])
            px += t
                   
        ### 6 parte:
        q6 = q5 + 1
        for i in range(q5,q6):
            b = {"rect":pygame.Rect(px, py, t, t), "color":branco}
            a.append(b)
            l.append([px,py])
            px += t
              
        ### 7 parte:
        q7 = q6 + 6
        for i in range(q6,q7):
            b = {"rect":pygame.Rect(px, py, t, t), "color":preto}
            a.append(b)
            l.append([px,py])
            px += t    
        
        for i in range(len(a)):
            pygame.draw.rect(windowSurface, a[i]["color"], a[i]["rect"])  
            
        return(a,l)
    
        
def jogo():
    
    pygame.time.delay(100)     # dá um delay necessário para vermos o desenho; 
    
    jogando = True 
    veloc1 = 1
    veloc2 = 2
        
    pos_x1 = 100
    pos_y1 = 100  
    
    t = 5
    
    descendo = True
        
    while jogando:
        for event in pygame.event.get():
            if event.type == pygame.QUIT:
                building(saindo = True, tam_pix = t, pos_x = pos_x1, pos_y =  pos_y1)
                jogando = False
                
        # Movimentação:
        
        # Lugar de descida 1: ######################################3
#        if l == 1:         
            # descendo:
        if pos_y1 <= 400 and descendo == True: 
                pos_y1 += veloc2
        else:
                descendo = False
            
            # subindo:
        if pos_y1 >= 100 and descendo == False: 
                pos_y1 -= veloc1
        else:        
                descendo = True
        
                
        windowSurface.fill(branco)
        
        b = building(saindo = False, tam_pix = t, pos_x = pos_x1, pos_y = pos_y1) 
        
        
        pygame.display.update()

#
jogo()
pygame.quit()
